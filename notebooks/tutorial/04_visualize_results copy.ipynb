# %%
# UPDATE THE BELOW WITH YOUR OWN PATH
REPO_BASE = '/home/bdanek2/multi-omics-pdd-FL-study/'

import os
import sys
sys.path.append(REPO_BASE)

# %%
# UPDATE THE BELOW WITH YOUR OWN PATH
# base of results directory
RESULTS_DIR = "/home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/experimental_results_dir/repro_test"

# UPDATE THE BELOW WITH YOUR OWN PATH
# where to output figures and tables
BASE_OUTPUT_PATH = '/home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/2-repro-generated_figures_tables'
os.makedirs(BASE_OUTPUT_PATH, exist_ok=True)

# once the overall table is generated for a split method, we can generate tables from the paper.
# table papers are from the uniform stratified split method (as can be seen in the string literals below)
INTERNAL_RESULTS_TABLE = 'k_averaged_results_table_k_all PPMI Uniform Stratified test.csv'
EXTERNAL_RESULTS_TABLE = 'k_averaged_results_table_k_all PDBP Uniform Stratified test.csv'

# %% [markdown]
# ## Generate Figures
# By running the below cell you will generate plots for figures 3 and 4, as well as paper tables 3, and 4, and precursor data for the table 1 and 2. The figures included in the paper are saved at the below paths:
# ```
# figure_3_ppmi = f'{BASE_OUTPUT_PATH}/global_experiments_k_all PPMI Linear Random test_compare_bar_chart.png'
# figure_3_pdbp = f'{BASE_OUTPUT_PATH}/global_experiments_k_all PDBP Linear Random test_compare_bar_chart.png'
#
# figure_4_ppmi = f'{BASE_OUTPUT_PATH}/global_experiments_k_all PPMI Uniform Stratified test_client_line_plot.png'
# figure_4_pdbp = f'{BASE_OUTPUT_PATH}/global_experiments_k_all PDBP Uniform Stratified test_client_line_plot.png'
# ```
#
# Note: to generate figure 5, run the notebook `federated_learning_multi_modality_ancestry/multi_modality_fl/results/hetrogeniety_scores.ipynb`

# %%
from federated_learning_multi_modality_ancestry.multi_modality_fl.results.compute_figures import create_tables, generate_plots


external_results_filename = [f'global_experiment_runner_k{i}_external test' for i in range(0, 2)]
internal_results_filenames = [f'global_experiment_runner_k{i}_internal test' for i in range(0, 2)]

"""
Each of the below are for a different heterogeniety/FL configuration
"""
# fig 3, 4, 5
results_directory = f'{RESULTS_DIR}/manual_experiments_linear_non_strat'
generate_plots(BASE_OUTPUT_PATH, "PDBP Linear Random", [0.5, 1], results_directory, external_results_filename, 'csv')
generate_plots(BASE_OUTPUT_PATH, "PPMI Linear Random", [0.5, 1], results_directory, internal_results_filenames, 'csv')

# fig 5
results_directory = f'{RESULTS_DIR}/manual_experiments_uniform_strat'
generate_plots(BASE_OUTPUT_PATH, "PDBP Uniform Stratified", [0.725, 0.95], results_directory, external_results_filename, 'csv')
generate_plots(BASE_OUTPUT_PATH, "PPMI Uniform Stratified", [0.65, 1], results_directory, internal_results_filenames, 'csv')

# fig 5
results_directory = f'{RESULTS_DIR}/manual_experiments_uniform_non_strat'
generate_plots(BASE_OUTPUT_PATH, "PDBP Uniform Random", [0.5, 1], results_directory, external_results_filename, 'csv')
generate_plots(BASE_OUTPUT_PATH, "PPMI Uniform Random", [0.5, 1], results_directory, internal_results_filenames, 'csv')
# Out:
# AdaBoostClassifier {'val_name': 'external test', 'algorithm_name': 'AdaBoostClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.
assifier {'val_name': 'external test', 'algorithm_name': 'FedAvg SGDClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.7475038936477917, 'auc_precision_recall': 0.8254663719654425, 'balanced_accuracy_score': 0.6809225164089443, 'precision_score': 0.7657534246575343, 'recall_score': 0.7851123595505618, 'fbeta_score_0.5': 0.7798295454545454, 'fbeta_score_1': 0.801186943620178, 'fbeta_score_2': 0.8994172789460351, 'log_loss': 0.5806688826264869, 'matthews_corrcoef': 0.36559328667140356}
# FedAvg XGBRFClassifier {'val_name': 'external test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 0, 'roc_auc_score': 0.7872886305484481, 'auc_precision_recall': 0.8762918755884168, 'balanced_accuracy_score': 0.6836133051507398, 'precision_score': 0.7451868629671574, 'recall_score': 0.9241573033707865, 'fbeta_score_0.5': 0.8268482490272373, 'fbeta_score_1': 0.8370273794002608, 'fbeta_score_2': 0.8981808994441637, 'log_loss': 0.6911533690549377, 'matthews_corrcoef': 0.43421668854563994}
# FedAvg XGBRFClassifier {'val_name': 'external test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 1, 'roc_auc_score': 0.7857694126154189, 'auc_precision_recall': 0.851079346055825, 'balanced_accuracy_score': 0.7219170653020359, 'precision_score': 0.7781862745098039, 'recall_score': 0.8918539325842697, 'fbeta_score_0.5': 0.8132214060860441, 'fbeta_score_1': 0.8341168569509737, 'fbeta_score_2': 0.8980827447023209, 'log_loss': 0.6912081514975905, 'matthews_corrcoef': 0.48111142341461316}
# FedAvg XGBRFClassifier {'val_name': 'external test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 0, 'roc_auc_score': 0.818929733563244, 'auc_precision_recall': 0.8744129860681851, 'balanced_accuracy_score': 0.6791981866725998, 'precision_score': 0.7423728813559322, 'recall_score': 0.922752808988764, 'fbeta_score_0.5': 0.8369164619164619, 'fbeta_score_1': 0.8391994478951, 'fbeta_score_2': 0.9030271934325295, 'log_loss': 0.6914095144575723, 'matthews_corrcoef': 0.4251250151469531}
# FedAvg XGBRFClassifier {'val_name': 'external test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.8029449187896317, 'auc_precision_recall': 0.8546203208047223, 'balanced_accuracy_score': 0.6951204249638447, 'precision_score': 0.7537399309551208, 'recall_score': 0.9199438202247191, 'fbeta_score_0.5': 0.8323598130841121, 'fbeta_score_1': 0.8402915838303512, 'fbeta_score_2': 0.8986349848331647, 'log_loss': 0.6915326272292641, 'matthews_corrcoef': 0.4517571588008546}
# FedProx μ = 0 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 LRClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 0, 'roc_auc_score': 0.7449486872844588, 'auc_precision_recall': 0.8169014098252587, 'balanced_accuracy_score': 0.6188535988430304, 'precision_score': 0.7024185068349106, 'recall_score': 0.9382022471910112, 'fbeta_score_0.5': 0.76644370122631, 'fbeta_score_1': 0.8080438756855576, 'fbeta_score_2': 0.9005580923389144, 'log_loss': 0.8934443887164355, 'matthews_corrcoef': 0.3218405642751353}
# FedProx μ = 0 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 LRClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 1, 'roc_auc_score': 0.7775718934252975, 'auc_precision_recall': 0.8447486960730253, 'balanced_accuracy_score': 0.6102875737011904, 'precision_score': 0.6958290946083419, 'recall_score': 0.9606741573033708, 'fbeta_score_0.5': 0.7980900409276945, 'fbeta_score_1': 0.817794028031688, 'fbeta_score_2': 0.9029200819672131, 'log_loss': 0.8376053637846519, 'matthews_corrcoef': 0.32717844056837975}
# FedProx μ = 0 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 LRClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 0, 'roc_auc_score': 0.7169491878963177, 'auc_precision_recall': 0.8052552215096269, 'balanced_accuracy_score': 0.5656010123484259, 'precision_score': 0.6716417910447762, 'recall_score': 0.9480337078651685, 'fbeta_score_0.5': 0.7589803012746233, 'fbeta_score_1': 0.791616766467066, 'fbeta_score_2': 0.900354071825999, 'log_loss': 0.8891584846549204, 'matthews_corrcoef': 0.21068164282587729}
# FedProx μ = 0 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 LRClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.7244166481254867, 'auc_precision_recall': 0.8129482033062712, 'balanced_accuracy_score': 0.5611163644454333, 'precision_score': 0.6686103012633625, 'recall_score': 0.9662921348314607, 'fbeta_score_0.5': 0.7591324200913241, 'fbeta_score_1': 0.7944412275622468, 'fbeta_score_2': 0.8997722095671982, 'log_loss': 0.8916701317467108, 'matthews_corrcoef': 0.21910428613066796}
# FedProx μ = 0 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 MLPClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 0, 'roc_auc_score': 0.7157115641339415, 'auc_precision_recall': 0.7890993776697488, 'balanced_accuracy_score': 0.6508440872177106, 'precision_score': 0.7331701346389229, 'recall_score': 0.8412921348314607, 'fbeta_score_0.5': 0.7652761457109283, 'fbeta_score_1': 0.8004750593824229, 'fbeta_score_2': 0.8987629386518556, 'log_loss': 1.3919959977892988, 'matthews_corrcoef': 0.3273726123628828}
# FedProx μ = 0 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 MLPClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 1, 'roc_auc_score': 0.7091062687729447, 'auc_precision_recall': 0.7971019198892353, 'balanced_accuracy_score': 0.6345533429747469, 'precision_score': 0.720763723150358, 'recall_score': 0.848314606741573, 'fbeta_score_0.5': 0.7529920212765957, 'fbeta_score_1': 0.7958833619210978, 'fbeta_score_2': 0.8990895295902882, 'log_loss': 1.0674011632252676, 'matthews_corrcoef': 0.2990272452924951}
# FedProx μ = 0 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 MLPClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 0, 'roc_auc_score': 0.6522207698297919, 'auc_precision_recall': 0.7563055658112195, 'balanced_accuracy_score': 0.6135206919568361, 'precision_score': 0.7114178168130489, 'recall_score': 0.7963483146067416, 'fbeta_score_0.5': 0.7279938587512794, 'fbeta_score_1': 0.7824126268320182, 'fbeta_score_2': 0.898989898989899, 'log_loss': 0.7483254580160625, 'matthews_corrcoef': 0.2414967010507779}
# FedProx μ = 0 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 0 MLPClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.6806443987095339, 'auc_precision_recall': 0.77813735315318, 'balanced_accuracy_score': 0.6085980086772722, 'precision_score': 0.7040094339622641, 'recall_score': 0.8384831460674157, 'fbeta_score_0.5': 0.7321009389671361, 'fbeta_score_1': 0.7890847072200113, 'fbeta_score_2': 0.898989898989899, 'log_loss': 0.8201079255832624, 'matthews_corrcoef': 0.24435274025538412}
# FedProx μ = 2 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 LRClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 0, 'roc_auc_score': 0.746318416954055, 'auc_precision_recall': 0.8164617899618539, 'balanced_accuracy_score': 0.6171153632217155, 'precision_score': 0.7020148462354189, 'recall_score': 0.9297752808988764, 'fbeta_score_0.5': 0.0, 'fbeta_score_1': 0.0, 'fbeta_score_2': 0.0, 'log_loss': 0.8947864100830553, 'matthews_corrcoef': 0.3110252492341084}
# FedProx μ = 2 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 LRClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 1, 'roc_auc_score': 0.7604467960841029, 'auc_precision_recall': 0.8294022188423729, 'balanced_accuracy_score': 0.610357103126043, 'precision_score': 0.6971904266389178, 'recall_score': 0.9410112359550562, 'fbeta_score_0.5': 0.7888349514563106, 'fbeta_score_1': 0.8062893081761007, 'fbeta_score_2': 0.8999746128459, 'log_loss': 0.8830508218933143, 'matthews_corrcoef': 0.3067138756902783}
# FedProx μ = 2 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 LRClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 0, 'roc_auc_score': 0.7135144343085993, 'auc_precision_recall': 0.7942863567879187, 'balanced_accuracy_score': 0.5604488819668484, 'precision_score': 0.6686332350049164, 'recall_score': 0.9550561797752809, 'fbeta_score_0.5': 0.759604190919674, 'fbeta_score_1': 0.7924743443557583, 'fbeta_score_2': 0.9001014198782962, 'log_loss': 0.9235908946830276, 'matthews_corrcoef': 0.2043482270389606}
# FedProx μ = 2 LRClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 LRClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.7482756702636556, 'auc_precision_recall': 0.8251185479287831, 'balanced_accuracy_score': 0.5571670931138057, 'precision_score': 0.6660323501427212, 'recall_score': 0.9831460674157303, 'fbeta_score_0.5': 0.7798013245033112, 'fbeta_score_1': 0.8040865384615383, 'fbeta_score_2': 0.9011776753712237, 'log_loss': 0.8990389436892656, 'matthews_corrcoef': 0.23461120388790926}
# FedProx μ = 2 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 MLPClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 0, 'roc_auc_score': 0.7147033874735788, 'auc_precision_recall': 0.7947669595204581, 'balanced_accuracy_score': 0.6369312493047058, 'precision_score': 0.7250308261405672, 'recall_score': 0.8258426966292135, 'fbeta_score_0.5': 0.7607433217189316, 'fbeta_score_1': 0.7917425622343656, 'fbeta_score_2': 0.898989898989899, 'log_loss': 1.3351161026715392, 'matthews_corrcoef': 0.2953268265988114}
# FedProx μ = 2 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 MLPClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 1, 'roc_auc_score': 0.6946163366336634, 'auc_precision_recall': 0.7935359205937806, 'balanced_accuracy_score': 0.6195697519190122, 'precision_score': 0.7117224880382775, 'recall_score': 0.8356741573033708, 'fbeta_score_0.5': 0.7457865168539326, 'fbeta_score_1': 0.7879503839338453, 'fbeta_score_2': 0.900126422250316, 'log_loss': 0.9446629435066892, 'matthews_corrcoef': 0.26509396983297506}
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# FedProx μ = 2 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 MLPClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 0, 'roc_auc_score': 0.7083066803871397, 'auc_precision_recall': 0.7858053493843525, 'balanced_accuracy_score': 0.635359884303037, 'precision_score': 0.7245657568238213, 'recall_score': 0.8202247191011236, 'fbeta_score_0.5': 0.0, 'fbeta_score_1': 0.0, 'fbeta_score_2': 0.0, 'log_loss': 1.1510718931177062, 'matthews_corrcoef': 0.2904706668154389}
# FedProx μ = 2 MLPClassifier {'val_name': 'external test', 'algorithm_name': 'FedProx μ = 2 MLPClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.7125549282456335, 'auc_precision_recall': 0.8028731910965988, 'balanced_accuracy_score': 0.6323144954944933, 'precision_score': 0.7210718635809987, 'recall_score': 0.8314606741573034, 'fbeta_score_0.5': 0.7597117794486214, 'fbeta_score_1': 0.7939814814814814, 'fbeta_score_2': 0.9001782531194296, 'log_loss': 1.0999476301159272, 'matthews_corrcoef': 0.2883935305103612}
# GradientBoostingClassifier {'val_name': 'external test', 'algorithm_name': 'GradientBoostingClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.8750451941261543, 'auc_precision_recall': 0.9196423305150971, 'balanced_accuracy_score': 0.700133496495717, 'precision_score': 0.7524972253052165, 'recall_score': 0.952247191011236, 'fbeta_score_0.5': 0.8664955070603336, 'fbeta_score_1': 0.8584969532836831, 'fbeta_score_2': 0.9115734720416124, 'log_loss': 0.5447445864090771, 'matthews_corrcoef': 0.48775174577478}
# GradientBoostingClassifier {'val_name': 'external test', 'algorithm_name': 'GradientBoostingClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.8592133440872177, 'auc_precision_recall': 0.9034825412424822, 'balanced_accuracy_score': 0.7350233618867505, 'precision_score': 0.7798594847775175, 'recall_score': 0.9353932584269663, 'fbeta_score_0.5': 0.8559268600252208, 'fbeta_score_1': 0.858447488584475, 'fbeta_score_2': 0.9108781127129751, 'log_loss': 0.5318190205061889, 'matthews_corrcoef': 0.532956948020459}
# KNeighborsClassifier {'val_name': 'external test', 'algorithm_name': 'KNeighborsClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.5979269801980198, 'auc_precision_recall': 0.7252687181665957, 'balanced_accuracy_score': 0.5595519523862499, 'precision_score': 0.6697722567287785, 'recall_score': 0.9087078651685393, 'fbeta_score_0.5': 0.7069493006993007, 'fbeta_score_1': 0.7817878956135481, 'fbeta_score_2': 0.8985360928823826, 'log_loss': 2.6861246076465326, 'matthews_corrcoef': 0.16781179641671037}
# KNeighborsClassifier {'val_name': 'external test', 'algorithm_name': 'KNeighborsClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.5838455334297474, 'auc_precision_recall': 0.7273952457725091, 'balanced_accuracy_score': 0.5583421403938147, 'precision_score': 0.6676528599605522, 'recall_score': 0.9508426966292135, 'fbeta_score_0.5': 0.709941275167785, 'fbeta_score_1': 0.7844727694090382, 'fbeta_score_2': 0.8986058301647655, 'log_loss': 3.151115958570786, 'matthews_corrcoef': 0.19459154652919564}
# LinearDiscriminantAnalysis {'val_name': 'external test', 'algorithm_name': 'LinearDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.7186457058627211, 'auc_precision_recall': 0.8001796208792464, 'balanced_accuracy_score': 0.662392924685727, 'precision_score': 0.7520435967302452, 'recall_score': 0.7752808988764045, 'fbeta_score_0.5': 0.7606199770378874, 'fbeta_score_1': 0.8016383850204799, 'fbeta_score_2': 0.9026369168356998, 'log_loss': 2.001483890087689, 'matthews_corrcoef': 0.32896376772598834}
# LinearDiscriminantAnalysis {'val_name': 'external test', 'algorithm_name': 'LinearDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.6845345700300367, 'auc_precision_recall': 0.7807679718725451, 'balanced_accuracy_score': 0.6272388474802537, 'precision_score': 0.7250996015936255, 'recall_score': 0.7668539325842697, 'fbeta_score_0.5': 0.7356532356532357, 'fbeta_score_1': 0.786556603773585, 'fbeta_score_2': 0.8983093615947515, 'log_loss': 1.9407565715339403, 'matthews_corrcoef': 0.26105354856971363}
# LogisticRegression {'val_name': 'external test', 'algorithm_name': 'LogisticRegression', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.7661968795194126, 'auc_precision_recall': 0.8364117334975218, 'balanced_accuracy_score': 0.6575606296584715, 'precision_score': 0.7315668202764977, 'recall_score': 0.8918539325842697, 'fbeta_score_0.5': 0.7880133185349611, 'fbeta_score_1': 0.8073170731707316, 'fbeta_score_2': 0.8988049834731756, 'log_loss': 1.0112658824963665, 'matthews_corrcoef': 0.36426939105978634}
# LogisticRegression {'val_name': 'external test', 'algorithm_name': 'LogisticRegression', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.770730198019802, 'auc_precision_recall': 0.8403668137668537, 'balanced_accuracy_score': 0.6645831015685838, 'precision_score': 0.734624145785877, 'recall_score': 0.9058988764044944, 'fbeta_score_0.5': 0.7885304659498208, 'fbeta_score_1': 0.8128544423440452, 'fbeta_score_2': 0.9014728288471305, 'log_loss': 0.9730275339922021, 'matthews_corrcoef': 0.38619814275095693}
# MLPClassifier {'val_name': 'external test', 'algorithm_name': 'MLPClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.6721774529981088, 'auc_precision_recall': 0.831822615631688, 'balanced_accuracy_score': 0.6244854822560908, 'precision_score': 0.7141162514827996, 'recall_score': 0.8455056179775281, 'fbeta_score_0.5': 0.7542372881355932, 'fbeta_score_1': 0.7895953757225433, 'fbeta_score_2': 0.898989898989899, 'log_loss': 9.066613257848115, 'matthews_corrcoef': 0.27834554218925767}
# MLPClassifier {'val_name': 'external test', 'algorithm_name': 'MLPClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.6575814884859272, 'auc_precision_recall': 0.8177026379412533, 'balanced_accuracy_score': 0.610037267771721, 'precision_score': 0.7056019070321812, 'recall_score': 0.8314606741573034, 'fbeta_score_0.5': 0.7405345211581292, 'fbeta_score_1': 0.7853463079564968, 'fbeta_score_2': 0.8983093615947515, 'log_loss': 8.977520373792943, 'matthews_corrcoef': 0.24483844264491225}
# QuadraticDiscriminantAnalysis {'val_name': 'external test', 'algorithm_name': 'QuadraticDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.5187451329402603, 'auc_precision_recall': 0.7214270327881596, 'balanced_accuracy_score': 0.5187451329402604, 'precision_score': 0.6604651162790698, 'recall_score': 0.398876404494382, 'fbeta_score_0.5': 0.687789799072643, 'fbeta_score_1': 0.7789934354485777, 'fbeta_score_2': 0.8980827447023209, 'log_loss': 18.53858158185775, 'matthews_corrcoef': 0.03702140649409545}
# QuadraticDiscriminantAnalysis {'val_name': 'external test', 'algorithm_name': 'QuadraticDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.5284305818222271, 'auc_precision_recall': 0.7124687890137329, 'balanced_accuracy_score': 0.5284305818222272, 'precision_score': 0.6928838951310862, 'recall_score': 0.2598314606741573, 'fbeta_score_0.5': 0.687789799072643, 'fbeta_score_1': 0.7789934354485777, 'fbeta_score_2': 0.8980827447023209, 'log_loss': 19.66898289782468, 'matthews_corrcoef': 0.06405262706984863}
# RandomForestClassifier {'val_name': 'external test', 'algorithm_name': 'RandomForestClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.7319223495383246, 'auc_precision_recall': 0.8272580246765328, 'balanced_accuracy_score': 0.5185991211480698, 'precision_score': 0.6467889908256881, 'recall_score': 0.9901685393258427, 'fbeta_score_0.5': 0.7548899755501223, 'fbeta_score_1': 0.7971946230274694, 'fbeta_score_2': 0.8992169739833291, 'log_loss': 0.5990817055656765, 'matthews_corrcoef': 0.11850950260543415}
# RandomForestClassifier {'val_name': 'external test', 'algorithm_name': 'RandomForestClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.7386788713983758, 'auc_precision_recall': 0.8275041247434104, 'balanced_accuracy_score': 0.5240849927689398, 'precision_score': 0.6494464944649446, 'recall_score': 0.9887640449438202, 'fbeta_score_0.5': 0.7663170163170163, 'fbeta_score_1': 0.7908653846153845, 'fbeta_score_2': 0.8996714682840536, 'log_loss': 0.5950653751489537, 'matthews_corrcoef': 0.13871312793507723}
# SGDClassifier {'val_name': 'external test', 'algorithm_name': 'SGDClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.6839522610968962, 'auc_precision_recall': 0.8528478048177142, 'balanced_accuracy_score': 0.6726137501390589, 'precision_score': 0.7429245283018868, 'recall_score': 0.8848314606741573, 'fbeta_score_0.5': 0.7706489675516224, 'fbeta_score_1': 0.8118572292800967, 'fbeta_score_2': 0.8980827447023209, 'log_loss': 9.438646914305604, 'matthews_corrcoef': 0.38839241498048316}
# SGDClassifier {'val_name': 'external test', 'algorithm_name': 'SGDClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.6791755896095227, 'auc_precision_recall': 0.8518153083083182, 'balanced_accuracy_score': 0.6644509956613639, 'precision_score': 0.7361111111111112, 'recall_score': 0.8932584269662921, 'fbeta_score_0.5': 0.7680136319376825, 'fbeta_score_1': 0.8123839009287926, 'fbeta_score_2': 0.8980827447023209, 'log_loss': 9.56783002016352, 'matthews_corrcoef': 0.3780419900348619}
# SVC {'val_name': 'external test', 'algorithm_name': 'SVC', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.7136969490488375, 'auc_precision_recall': 0.8153474378179161, 'balanced_accuracy_score': 0.6040438313494271, 'precision_score': 0.697986577181208, 'recall_score': 0.8764044943820225, 'fbeta_score_0.5': 0.74792654028436, 'fbeta_score_1': 0.7951105937136204, 'fbeta_score_2': 0.9008097165991902, 'log_loss': 0.6198907687127803, 'matthews_corrcoef': 0.25051386351345173}
# SVC {'val_name': 'external test', 'algorithm_name': 'SVC', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.6953133691178106, 'auc_precision_recall': 0.8041083788886978, 'balanced_accuracy_score': 0.5799657915229726, 'precision_score': 0.6854838709677419, 'recall_score': 0.8356741573033708, 'fbeta_score_0.5': 0.7363013698630136, 'fbeta_score_1': 0.7912211592571751, 'fbeta_score_2': 0.9019508487458828, 'log_loss': 0.6460379679330325, 'matthews_corrcoef': 0.18487543650229923}
# XGBClassifier {'val_name': 'external test', 'algorithm_name': 'XGBClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.8652728334631217, 'auc_precision_recall': 0.9089610517631872, 'balanced_accuracy_score': 0.6865543998220047, 'precision_score': 0.7447280799112098, 'recall_score': 0.9424157303370787, 'fbeta_score_0.5': 0.8622320302648172, 'fbeta_score_1': 0.8539638386648123, 'fbeta_score_2': 0.9052711993888464, 'log_loss': 0.7049196319105588, 'matthews_corrcoef': 0.4546576949306254}
# XGBClassifier {'val_name': 'external test', 'algorithm_name': 'XGBClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.8683060546223162, 'auc_precision_recall': 0.9088017655281423, 'balanced_accuracy_score': 0.7311436199799755, 'precision_score': 0.7775175644028103, 'recall_score': 0.9325842696629213, 'fbeta_score_0.5': 0.8671465968586387, 'fbeta_score_1': 0.8598382749326147, 'fbeta_score_2': 0.9061779031017688, 'log_loss': 0.6497347530932576, 'matthews_corrcoef': 0.5241589485826915}
# XGBRFClassifier {'val_name': 'external test', 'algorithm_name': 'XGBRFClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.8366892869062188, 'auc_precision_recall': 0.8963594200207866, 'balanced_accuracy_score': 0.7168275114028257, 'precision_score': 0.7673611111111112, 'recall_score': 0.9311797752808989, 'fbeta_score_0.5': 0.8501118568232663, 'fbeta_score_1': 0.8573378839590443, 'fbeta_score_2': 0.9068753206772704, 'log_loss': 2.5854939272852464, 'matthews_corrcoef': 0.4984457745322666}
# XGBRFClassifier {'val_name': 'external test', 'algorithm_name': 'XGBRFClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.8371116781621983, 'auc_precision_recall': 0.8950520640280457, 'balanced_accuracy_score': 0.7383051507397931, 'precision_score': 0.7878048780487805, 'recall_score': 0.9073033707865169, 'fbeta_score_0.5': 0.8488914819136523, 'fbeta_score_1': 0.8555932203389831, 'fbeta_score_2': 0.908739365815932, 'log_loss': 2.4428601265903604, 'matthews_corrcoef': 0.5188494045129758}
# Wrote reconstructed_results_df to:  /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/2-repro-generated_figures_tables/raw_results_table_k_all PDBP Linear Random test.csv
# Wrote mean_std_reconstructed_metrics_table to:  /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/2-repro-generated_figures_tables/k_averaged_results_table_k_all PDBP Linear Random test.csv
# {'LogisticRegression': {'LogisticRegression': {'score': 0.8383892736321878, 'error': 0.0027966640785816567, 'color': 'lightsalmon'}, 'FedAvg LRClassifier': {'score': 0.8353394949317656, 'error': 0.01051960633518508, 'color': 'yellowgreen'}, 'FedProx μ = 0 LRClassifier': {'score': 0.830825052949142, 'error': 0.01969100494343862, 'color': 'skyblue'}, 'FedProx μ = 2 LRClassifier': {'score': 0.8229320044021133, 'error': 0.009150265012877225, 'color': 'dodgerblue'}}, 'MLPClassifier': {'MLPClassifier': {'score': 0.8247626267864707, 'error': 0.009984331975109192, 'color': 'lightsalmon'}, 'FedAvg MLPClassifier': {'score': 0.795956310061228, 'error': 0.020490751115772157, 'color': 'yellowgreen'}, 'FedProx μ = 0 MLPClassifier': {'score': 0.793100648779492, 'error': 0.005658651870130539, 'color': 'skyblue'}, 'FedProx μ = 2 MLPClassifier': {'score': 0.7941514400571194, 'error': 0.0008704759729582122, 'color': 'dodgerblue'}}, 'SGDClassifier': {'SGDClassifier': {'score': 0.8523315565630162, 'error': 0.0007300852833453258, 'color': 'lightsalmon'}, 'FedAvg SGDClassifier': {'score': 0.8314989455774373, 'error': 0.013586754864558973, 'color': 'yellowgreen'}}, 'XGBRFClassifier': {'XGBRFClassifier': {'score': 0.8957057420244161, 'error': 0.0009244402878919216, 'color': 'lightsalmon'}, 'FedAvg XGBRFClassifier': {'score': 0.8636856108221209, 'error': 0.017827950603361748, 'color': 'yellowgreen'}}}
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# AdaBoostClassifier {'val_name': 'internal test', 'algorithm_name': 'AdaBoostClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.8561368209255533, 'auc_precision_recall': 0.9297980728978906, 'balanced_accuracy_score': 0.7401911468812876, 'precision_score': 0.8493150684931506, 'recall_score': 0.8732394366197183, 'fbeta_score_0.5': 0.893470790378007, 'fbeta_score_1': 0.8860759493670887, 'fbeta_score_2': 0.9466666666666668, 'log_loss': 0.6375830164115518, 'matthews_corrcoef': 0.491639850011913}
# AdaBoostClassifier {'val_name': 'internal test', 'algorithm_name': 'AdaBoostClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.9114688128772636, 'auc_precision_recall': 0.9442036003848993, 'balanced_accuracy_score': 0.8327464788732395, 'precision_score': 0.9027777777777778, 'recall_score': 0.9154929577464789, 'fbeta_score_0.5': 0.9183673469387755, 'fbeta_score_1': 0.9333333333333333, 'fbeta_score_2': 0.9641873278236915, 'log_loss': 0.6274245068038505, 'matthews_corrcoef': 0.6729821168333263}
# BaggingClassifier {'val_name': 'internal test', 'algorithm_name': 'BaggingClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0
assifier {'val_name': 'internal test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 2, 'fold_idx': 1, 'roc_auc_score': 0.8843058350100603, 'auc_precision_recall': 0.952660139254601, 'balanced_accuracy_score': 0.7796780684104627, 'precision_score': 0.8823529411764706, 'recall_score': 0.8450704225352113, 'fbeta_score_0.5': 0.913312693498452, 'fbeta_score_1': 0.8805970149253731, 'fbeta_score_2': 0.9366754617414248, 'log_loss': 0.6907431817376254, 'matthews_corrcoef': 0.5432019170155502}
# FedAvg XGBRFClassifier {'val_name': 'internal test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 0, 'roc_auc_score': 0.8938631790744467, 'auc_precision_recall': 0.9315098486321227, 'balanced_accuracy_score': 0.8148893360160966, 'precision_score': 0.8904109589041096, 'recall_score': 0.9154929577464789, 'fbeta_score_0.5': 0.9322033898305084, 'fbeta_score_1': 0.9027777777777778, 'fbeta_score_2': 0.9358288770053476, 'log_loss': 0.6910825863241418, 'matthews_corrcoef': 0.6445372693349896}
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# FedAvg XGBRFClassifier {'val_name': 'internal test', 'algorithm_name': 'FedAvg XGBRFClassifier', 'split_method': 'linear', 'num_clients': 4, 'fold_idx': 1, 'roc_auc_score': 0.8654426559356136, 'auc_precision_recall': 0.9492363090932718, 'balanced_accuracy_score': 0.7688631790744467, 'precision_score': 0.8714285714285714, 'recall_score': 0.8591549295774648, 'fbeta_score_0.5': 0.9059233449477352, 'fbeta_score_1': 0.8776978417266187, 'fbeta_score_2': 0.931758530183727, 'log_loss': 0.6912024345399513, 'matthews_corrcoef': 0.5321345976168722}
# ...
# GradientBoostingClassifier {'val_name': 'internal test', 'algorithm_name': 'GradientBoostingClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.8913480885311871, 'auc_precision_recall': 0.9499486761304954, 'balanced_accuracy_score': 0.7829476861167002, 'precision_score': 0.875, 'recall_score': 0.8873239436619719, 'fbeta_score_0.5': 0.9163987138263665, 'fbeta_score_1': 0.8936170212765958, 'fbeta_score_2': 0.9491978609625669, 'log_loss': 0.380275657165445, 'matthews_corrcoef': 0.5722637047902435}
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:305: RuntimeWarning: invalid value encountered in divide
#   f_beta = lambda beta, precision, recall: ((1 + beta**2) * (precision * recall)) / ((beta**2) * precision + recall)
# KNeighborsClassifier {'val_name': 'internal test', 'algorithm_name': 'KNeighborsClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.5213782696177063, 'auc_precision_recall': 0.711430310535801, 'balanced_accuracy_score': 0.5545774647887324, 'precision_score': 0.7439024390243902, 'recall_score': 0.8591549295774648, 'fbeta_score_0.5': 0.7667386609071274, 'fbeta_score_1': 0.8402366863905326, 'fbeta_score_2': 0.9293193717277487, 'log_loss': 2.6798732675371917, 'matthews_corrcoef': 0.13035273775345327}
# KNeighborsClassifier {'val_name': 'internal test', 'algorithm_name': 'KNeighborsClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.6468812877263581, 'auc_precision_recall': 0.8364817670447113, 'balanced_accuracy_score': 0.49673038229376254, 'precision_score': 0.7157894736842105, 'recall_score': 0.9577464788732394, 'fbeta_score_0.5': 0.7938718662952645, 'fbeta_score_1': 0.8352941176470587, 'fbeta_score_2': 0.9268929503916449, 'log_loss': 2.59689184846491, 'matthews_corrcoef': -0.01495696109387242}
# LinearDiscriminantAnalysis {'val_name': 'internal test', 'algorithm_name': 'LinearDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.7479879275653923, 'auc_precision_recall': 0.8399635979906536, 'balanced_accuracy_score': 0.6594567404426559, 'precision_score': 0.8275862068965517, 'recall_score': 0.676056338028169, 'fbeta_score_0.5': 0.0, 'fbeta_score_1': 0.0, 'fbeta_score_2': 0.0, 'log_loss': 1.8195245226611132, 'matthews_corrcoef': 0.2915916898249568}
# LinearDiscriminantAnalysis {'val_name': 'internal test', 'algorithm_name': 'LinearDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.8199195171026158, 'auc_precision_recall': 0.9215887445512616, 'balanced_accuracy_score': 0.7872233400402414, 'precision_score': 0.9032258064516129, 'recall_score': 0.7887323943661971, 'fbeta_score_0.5': 0.8842443729903536, 'fbeta_score_1': 0.8695652173913044, 'fbeta_score_2': 0.9358288770053476, 'log_loss': 1.0954360480154486, 'matthews_corrcoef': 0.5347628228077644}
# LogisticRegression {'val_name': 'internal test', 'algorithm_name': 'LogisticRegression', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.8088531187122737, 'auc_precision_recall': 0.8799168662920798, 'balanced_accuracy_score': 0.8008048289738431, 'precision_score': 0.8873239436619719, 'recall_score': 0.8873239436619719, 'fbeta_score_0.5': 0.8913649025069638, 'fbeta_score_1': 0.8951048951048951, 'fbeta_score_2': 0.9366754617414248, 'log_loss': 0.6929074083853718, 'matthews_corrcoef': 0.6016096579476862}
# LogisticRegression {'val_name': 'internal test', 'algorithm_name': 'LogisticRegression', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.841046277665996, 'auc_precision_recall': 0.9349149810687167, 'balanced_accuracy_score': 0.7152917505030181, 'precision_score': 0.8356164383561644, 'recall_score': 0.8591549295774648, 'fbeta_score_0.5': 0.873015873015873, 'fbeta_score_1': 0.8666666666666667, 'fbeta_score_2': 0.9366754617414248, 'log_loss': 0.6313868599040893, 'matthews_corrcoef': 0.44067404357088746}
# MLPClassifier {'val_name': 'internal test', 'algorithm_name': 'MLPClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.7193158953722334, 'auc_precision_recall': 0.8849585516894047, 'balanced_accuracy_score': 0.6654929577464789, 'precision_score': 0.8082191780821918, 'recall_score': 0.8309859154929577, 'fbeta_score_0.5': 0.8358208955223881, 'fbeta_score_1': 0.8701298701298701, 'fbeta_score_2': 0.931758530183727, 'log_loss': 7.286441433656654, 'matthews_corrcoef': 0.3387424306888364}
# MLPClassifier {'val_name': 'internal test', 'algorithm_name': 'MLPClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.7150402414486923, 'auc_precision_recall': 0.8812060041355083, 'balanced_accuracy_score': 0.6838531187122736, 'precision_score': 0.8307692307692308, 'recall_score': 0.7605633802816901, 'fbeta_score_0.5': 0.8157099697885197, 'fbeta_score_1': 0.8447204968944099, 'fbeta_score_2': 0.9293193717277487, 'log_loss': 8.45298862984864, 'matthews_corrcoef': 0.34874906351410556}
# QuadraticDiscriminantAnalysis {'val_name': 'internal test', 'algorithm_name': 'QuadraticDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.5040241448692152, 'auc_precision_recall': 0.7807951774542012, 'balanced_accuracy_score': 0.5040241448692153, 'precision_score': 0.7209302325581395, 'recall_score': 0.43661971830985913, 'fbeta_score_0.5': 0.7601713062098501, 'fbeta_score_1': 0.8352941176470587, 'fbeta_score_2': 0.9268929503916449, 'log_loss': 18.932019961960524, 'matthews_corrcoef': 0.007312797565143906}
# QuadraticDiscriminantAnalysis {'val_name': 'internal test', 'algorithm_name': 'QuadraticDiscriminantAnalysis', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.5543259557344065, 'auc_precision_recall': 0.8032437046521553, 'balanced_accuracy_score': 0.5543259557344065, 'precision_score': 0.7777777777777778, 'recall_score': 0.39436619718309857, 'fbeta_score_0.5': 0.7601713062098501, 'fbeta_score_1': 0.8352941176470587, 'fbeta_score_2': 0.9268929503916449, 'log_loss': 18.567942654999744, 'matthews_corrcoef': 0.10172414213090171}
# RandomForestClassifier {'val_name': 'internal test', 'algorithm_name': 'RandomForestClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.9024144869215291, 'auc_precision_recall': 0.9399535081794066, 'balanced_accuracy_score': 0.5535714285714286, 'precision_score': 0.7395833333333334, 'recall_score': 1.0, 'fbeta_score_0.5': 0.9077809798270893, 'fbeta_score_1': 0.9271523178807948, 'fbeta_score_2': 0.9673024523160763, 'log_loss': 0.47673117863940134, 'matthews_corrcoef': 0.2814979066149008}
# RandomForestClassifier {'val_name': 'internal test', 'algorithm_name': 'RandomForestClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.862927565392354, 'auc_precision_recall': 0.9443443016090143, 'balanced_accuracy_score': 0.5178571428571429, 'precision_score': 0.7244897959183674, 'recall_score': 1.0, 'fbeta_score_0.5': 0.8687258687258688, 'fbeta_score_1': 0.8846153846153846, 'fbeta_score_2': 0.9441489361702127, 'log_loss': 0.4958398272148847, 'matthews_corrcoef': 0.1608559466370862}
# SGDClassifier {'val_name': 'internal test', 'algorithm_name': 'SGDClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.760814889336016, 'auc_precision_recall': 0.9109482362870583, 'balanced_accuracy_score': 0.7580482897384306, 'precision_score': 0.8611111111111112, 'recall_score': 0.8732394366197183, 'fbeta_score_0.5': 0.863509749303621, 'fbeta_score_1': 0.8734177215189873, 'fbeta_score_2': 0.9358288770053476, 'log_loss': 6.8592000242346405, 'matthews_corrcoef': 0.521904498768702}
# SGDClassifier {'val_name': 'internal test', 'algorithm_name': 'SGDClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.7663480885311872, 'auc_precision_recall': 0.9092802696206843, 'balanced_accuracy_score': 0.7228370221327969, 'precision_score': 0.8507462686567164, 'recall_score': 0.8028169014084507, 'fbeta_score_0.5': 0.8666666666666667, 'fbeta_score_1': 0.8843537414965986, 'fbeta_score_2': 0.9268929503916449, 'log_loss': 8.512353861260308, 'matthews_corrcoef': 0.42915397683104933}
# SVC {'val_name': 'internal test', 'algorithm_name': 'SVC', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.8435613682092555, 'auc_precision_recall': 0.9239834251706888, 'balanced_accuracy_score': 0.7256036217303823, 'precision_score': 0.8333333333333334, 'recall_score': 0.9154929577464789, 'fbeta_score_0.5': 0.8715596330275229, 'fbeta_score_1': 0.9019607843137255, 'fbeta_score_2': 0.942622950819672, 'log_loss': 0.42154286517999917, 'matthews_corrcoef': 0.49708116132358066}
# SVC {'val_name': 'internal test', 'algorithm_name': 'SVC', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.8707243460764588, 'auc_precision_recall': 0.9394843300767973, 'balanced_accuracy_score': 0.7434607645875251, 'precision_score': 0.8441558441558441, 'recall_score': 0.9154929577464789, 'fbeta_score_0.5': 0.8934169278996865, 'fbeta_score_1': 0.8859060402684563, 'fbeta_score_2': 0.9358288770053476, 'log_loss': 0.404832801773015, 'matthews_corrcoef': 0.5274854252150617}
# XGBClassifier {'val_name': 'internal test', 'algorithm_name': 'XGBClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.9240442655935613, 'auc_precision_recall': 0.9543302524296065, 'balanced_accuracy_score': 0.8538732394366197, 'precision_score': 0.9066666666666666, 'recall_score': 0.9577464788732394, 'fbeta_score_0.5': 0.9366391184573004, 'fbeta_score_1': 0.9444444444444444, 'fbeta_score_2': 0.9620596205962059, 'log_loss': 0.3194669973324589, 'matthews_corrcoef': 0.7437888349430337}
# XGBClassifier {'val_name': 'internal test', 'algorithm_name': 'XGBClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.93158953722334, 'auc_precision_recall': 0.9722510692228311, 'balanced_accuracy_score': 0.8971327967806841, 'precision_score': 0.9552238805970149, 'recall_score': 0.9014084507042254, 'fbeta_score_0.5': 0.943952802359882, 'fbeta_score_1': 0.927536231884058, 'fbeta_score_2': 0.9568733153638814, 'log_loss': 0.3129751613879795, 'matthews_corrcoef': 0.7648240738332132}
# XGBRFClassifier {'val_name': 'internal test', 'algorithm_name': 'XGBRFClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 0, 'roc_auc_score': 0.9481891348088531, 'auc_precision_recall': 0.9740647649982013, 'balanced_accuracy_score': 0.8360160965794768, 'precision_score': 0.8947368421052632, 'recall_score': 0.9577464788732394, 'fbeta_score_0.5': 0.9734513274336283, 'fbeta_score_1': 0.9565217391304348, 'fbeta_score_2': 0.9556786703601108, 'log_loss': 0.7047860206806373, 'matthews_corrcoef': 0.716683744255012}
# XGBRFClassifier {'val_name': 'internal test', 'algorithm_name': 'XGBRFClassifier', 'split_method': 'central', 'num_clients': 0, 'fold_idx': 1, 'roc_auc_score': 0.9175050301810865, 'auc_precision_recall': 0.9678236343679897, 'balanced_accuracy_score': 0.8511066398390341, 'precision_score': 0.9375, 'recall_score': 0.8450704225352113, 'fbeta_score_0.5': 0.9329446064139942, 'fbeta_score_1': 0.9230769230769231, 'fbeta_score_2': 0.9408602150537636, 'log_loss': 0.9062503961056485, 'matthews_corrcoef': 0.6615355980698645}
# Wrote reconstructed_results_df to:  /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/2-repro-generated_figures_tables/raw_results_table_k_all PPMI Uniform Random test.csv
# Wrote mean_std_reconstructed_metrics_table to:  /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/2-repro-generated_figures_tables/k_averaged_results_table_k_all PPMI Uniform Random test.csv
# {'LogisticRegression': {'LogisticRegression': {'score': 0.9074159236803983, 'error': 0.03888953991103606, 'color': 'lightsalmon'}, 'FedAvg LRClassifier': {'score': 0.8880379404413055, 'error': 0.05337428682827466, 'color': 'yellowgreen'}, 'FedProx μ = 0 LRClassifier': {'score': 0.8911835775816007, 'error': 0.09517502999229735, 'color': 'skyblue'}, 'FedProx μ = 2 LRClassifier': {'score': 0.8950304390047352, 'error': 0.05162260078617078, 'color': 'dodgerblue'}}, 'MLPClassifier': {'MLPClassifier': {'score': 0.8830822779124565, 'error': 0.0026534518220851524, 'color': 'lightsalmon'}, 'FedAvg MLPClassifier': {'score': 0.8506848601639607, 'error': 0.08505447262144535, 'color': 'yellowgreen'}, 'FedProx μ = 0 MLPClassifier': {'score': 0.8735869140294286, 'error': 0.06437902677035579, 'color': 'skyblue'}, 'FedProx μ = 2 MLPClassifier': {'score': 0.8339448005476229, 'error': 0.08435510510340516, 'color': 'dodgerblue'}}, 'SGDClassifier': {'SGDClassifier': {'score': 0.9101142529538713, 'error': 0.0011794305405861587, 'color': 'lightsalmon'}, 'FedAvg SGDClassifier': {'score': 0.8955816177437075, 'error': 0.07080802653869929, 'color': 'yellowgreen'}}, 'XGBRFClassifier': {'XGBRFClassifier': {'score': 0.9709441996830954, 'error': 0.004413145790893646, 'color': 'lightsalmon'}, 'FedAvg XGBRFClassifier': {'score': 0.932302919183805, 'error': 0.016706749450023192, 'color': 'yellowgreen'}}}
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent
# cent

# %% [markdown]
# ## Generate Tables
# to generate csv forms of the tables included in the paper run the below cells:

# %%
# generate table 1
dataset = 'PPMI'
processed_data_ppmi = f'{BASE_OUTPUT_PATH}/k_averaged_results_table_k_all {dataset} Uniform Stratified test.csv'
ppmi_table_output = f'{BASE_OUTPUT_PATH}/{dataset}_n_2_clients_cleaned_combined.csv'
create_tables(dataset, processed_data_ppmi, ppmi_table_output)

# generate table 2
dataset = 'PDBP'
processed_data_pdbp = f'{BASE_OUTPUT_PATH}/k_averaged_results_table_k_all {dataset} Uniform Stratified test.csv'
pdbp_table_output = f'{BASE_OUTPUT_PATH}/{dataset}_n_2_clients_cleaned_combined.csv'
create_tables(dataset, processed_data_pdbp, pdbp_table_output)

table_1 = f'{BASE_OUTPUT_PATH}/PPMI_n_2_clients_cleaned_combined.csv'
table_2 = f'{BASE_OUTPUT_PATH}/PDBP_n_2_clients_cleaned_combined.csv'
# Out:
# =====================================
# Score table of all algorithms for: PPMI
# |                                           |   roc_auc_score |   auc_precision_recall |   balanced_accuracy_score |   precision_score |   recall_score |   fbeta_score_0.5 |   fbeta_score_1 |   fbeta_score_2 |   log_loss |   matthews_corrcoef |   roc_auc_score_std |   auc_precision_recall_std |   balanced_accuracy_score_std |   precision_score_std |   recall_score_std |   fbeta_score_0.5_std |   fbeta_score_1_std |   fbeta_score_2_std |   log_loss_std |   matthews_corrcoef_std |
# |:------------------------------------------|----------------:|-----------------------:|--------------------------:|------------------:|---------------:|------------------:|----------------:|----------------:|-----------:|--------------------:|--------------------:|---------------------------:|------------------------------:|----------------------:|-------------------:|----------------------:|--------------------:|--------------------:|---------------:|------------------------:|
# | ('PPMI', 'AdaBoost')                      |           0.884 |                  0.937 |                     0.786 |             0.876 |          0.894 |             0.906 |           0.91  |           0.955 |      0.633 |               0.582 |               0.039 |                      0.01  |                         0.065 |                 0.038 |               0.03 |                 0.018 |               0.033 |               0.012 |          0.007 |                   0.128 |
# | ('PPMI', 'XGB')                           |           0.928 |                  0.963 |                     0.876 |             0.931 |          0.93  |             0.94  |           0.936 |           0.959 |      0.316 |               0.754 |               0.005 |                      0.013 |                         0.031 |                 0.034 |               0.04 |                 0.005 |               0.012 |               0.004 |          0.005 |                   0.015 |
# | ('PPMI', 'XGBRF')                         |           0.933 |                  0.971 |                     0.844 |             0.916 |          0.901 |             0.953 |           0.94  |           0.948 |      0.806 |               0.689 |               0.022 |                      0.004 |                         0.011 |                 0.03  |               0.08 |                 0.029 |               0.024 |               0.01  |          0.142 |                   0.039 |
# | ('PPMI', 'FedAvg LR')                     |           0.827 |                  0.899 |                     0.724 |             0.83  |          0.93  |             0.873 |           0.889 |           0.943 |      0.538 |               0.506 |               0.042 |                      0.054 |                         0.038 |                 0.022 |               0    |                 0.009 |               0.006 |               0.005 |          0.106 |                   0.065 |
# | ('PPMI', 'FedAvg MLP')                    |           0.7   |                  0.833 |                     0.616 |             0.792 |          0.697 |             0.41  |           0.434 |           0.467 |      0.771 |               0.218 |               0.095 |                      0.1   |                         0.01  |                 0.011 |               0.03 |                 0.579 |               0.614 |               0.661 |          0.085 |                   0.015 |
# | ('PPMI', 'FedAvg SGD')                    |           0.837 |                  0.926 |                     0.777 |             0.925 |          0.697 |             0.881 |           0.863 |           0.939 |      0.53  |               0.501 |               0.036 |                      0.008 |                         0.05  |                 0.029 |               0.05 |                 0.036 |               0.018 |               0.007 |          0.046 |                   0.092 |
# | ('PPMI', 'FedAvg XGBRF')                  |           0.838 |                  0.934 |                     0.774 |             0.88  |          0.852 |             0.883 |           0.875 |           0.929 |      0.691 |               0.54  |               0.03  |                      0.009 |                         0.063 |                 0.057 |               0.05 |                 0.03  |               0.017 |               0.003 |          0     |                   0.082 |
# | ('PPMI', 'FedProx μ = 0 LR')              |           0.832 |                  0.901 |                     0.67  |             0.8   |          0.93  |             0.447 |           0.449 |           0.478 |      0.531 |               0.412 |               0.064 |                      0.066 |                         0.028 |                 0.017 |               0.02 |                 0.632 |               0.636 |               0.677 |          0.164 |                   0.032 |
# | ('PPMI', 'FedProx μ = 0 MLP')             |           0.731 |                  0.852 |                     0.645 |             0.805 |          0.754 |             0.831 |           0.858 |           0.938 |      0.98  |               0.277 |               0.042 |                      0.068 |                         0.005 |                 0.002 |               0.01 |                 0.018 |               0.011 |               0.005 |          0.077 |                   0.011 |
# | ('PPMI', 'FedProx μ = 2 LR')              |           0.799 |                  0.891 |                     0.661 |             0.795 |          0.93  |             0.859 |           0.87  |           0.94  |      0.565 |               0.395 |               0.022 |                      0.038 |                         0     |                 0     |               0    |                 0.006 |               0.009 |               0.009 |          0.049 |                   0     |
# | ('PPMI', 'FedProx μ = 2 MLP')             |           0.736 |                  0.846 |                     0.645 |             0.805 |          0.754 |             0.415 |           0.43  |           0.465 |      0.785 |               0.277 |               0.062 |                      0.082 |                         0.046 |                 0.032 |               0.01 |                 0.587 |               0.609 |               0.657 |          0.091 |                   0.08  |
# =====================================
# Score table of all algorithms for: PDBP
# |                                           |   roc_auc_score |   auc_precision_recall |   balanced_accuracy_score |   precision_score |   recall_score |   fbeta_score_0.5 |   fbeta_score_1 |   fbeta_score_2 |   log_loss |   matthews_corrcoef |   roc_auc_score_std |   auc_precision_recall_std |   balanced_accuracy_score_std |   precision_score_std |   recall_score_std |   fbeta_score_0.5_std |   fbeta_score_1_std |   fbeta_score_2_std |   log_loss_std |   matthews_corrcoef_std |
# |:------------------------------------------|----------------:|-----------------------:|--------------------------:|------------------:|---------------:|------------------:|----------------:|----------------:|-----------:|--------------------:|--------------------:|---------------------------:|------------------------------:|----------------------:|-------------------:|----------------------:|--------------------:|--------------------:|---------------:|------------------------:|
# | ('PPMI', 'AdaBoost')                      |           0.846 |                  0.902 |                     0.676 |             0.737 |          0.948 |             0.843 |           0.836 |           0.908 |      0.634 |               0.44  |               0.03  |                      0.022 |                         0.032 |                 0.022 |              0.014 |                 0.028 |               0.014 |               0.002 |          0.003 |                   0.044 |
# | ('PPMI', 'Bagging')                       |           0.812 |                  0.869 |                     0.68  |             0.74  |          0.947 |             0.827 |           0.841 |           0.905 |      1.396 |               0.448 |               0.017 |                      0.016 |                         0.015 |                 0.012 |              0.02  |                 0.014 |               0.008 |               0.001 |          0.135 |                   0.007 |
# | ('PPMI', 'GradientBoosting')              |           0.867 |                  0.912 |                     0.718 |             0.766 |          0.944 |             0.861 |           0.858 |           0.911 |      0.538 |               0.51  |               0.011 |                      0.011 |                         0.025 |                 0.019 |              0.012 |                 0.007 |               0     |               0     |          0.009 |                   0.032 |
# | ('PPMI', 'KNeighbors')                    |           0.591 |                  0.726 |                     0.559 |             0.669 |          0.93  |             0.708 |           0.783 |           0.899 |      2.919 |               0.181 |               0.01  |                      0.002 |                         0.001 |                 0.001 |              0.03  |                 0.002 |               0.002 |               0     |          0.329 |                   0.019 |
# | ('PPMI', 'LinearDiscriminantAnalysis')    |           0.702 |                  0.79  |                     0.645 |             0.739 |          0.771 |             0.748 |           0.794 |           0.9   |      1.971 |               0.295 |               0.024 |                      0.014 |                         0.025 |                 0.019 |              0.006 |                 0.018 |               0.011 |               0.003 |          0.043 |                   0.048 |
# | ('PPMI', 'LogisticRegression')            |           0.768 |                  0.838 |                     0.661 |             0.733 |          0.899 |             0.788 |           0.81  |           0.9   |      0.992 |               0.375 |               0.003 |                      0.003 |                         0.005 |                 0.002 |              0.01  |                 0     |               0.004 |               0.002 |          0.027 |                   0.016 |
# | ('PPMI', 'MLP')                           |           0.665 |                  0.825 |                     0.617 |             0.71  |          0.838 |             0.747 |           0.787 |           0.899 |      9.022 |               0.262 |               0.01  |                      0.01  |                         0.01  |                 0.006 |              0.01  |                 0.01  |               0.003 |               0     |          0.063 |                   0.024 |
# | ('PPMI', 'QuadraticDiscriminantAnalysis') |           0.524 |                  0.717 |                     0.524 |             0.677 |          0.329 |             0.688 |           0.779 |           0.898 |     19.104 |               0.051 |               0.007 |                      0.006 |                         0.007 |                 0.023 |              0.098 |                 0     |               0     |               0     |          0.799 |                   0.019 |
# | ('PPMI', 'FedProx μ = 0 MLP')             |           0.701 |                  0.794 |                     0.62  |             0.713 |          0.825 |             0.746 |           0.792 |           0.899 |      1.201 |               0.262 |               0     |                      0.008 |                         0.01  |                 0.007 |              0.007 |                 0.005 |               0.003 |               0     |          0.155 |                   0.017 |
# | ('PPMI', 'FedProx μ = 2 LR')              |           0.754 |                  0.828 |                     0.596 |             0.688 |          0.956 |             0.782 |           0.803 |           0.899 |      0.864 |               0.293 |               0.009 |                      0.008 |                         0.003 |                 0.003 |              0.016 |                 0.004 |               0.002 |               0.001 |          0.012 |                   0.01  |
# | ('PPMI', 'FedProx μ = 2 MLP')             |           0.676 |                  0.773 |                     0.606 |             0.705 |          0.802 |             0.733 |           0.788 |           0.899 |      1.134 |               0.228 |               0.016 |                      0.012 |                         0.003 |                 0.004 |              0.016 |                 0.01  |               0.005 |               0     |          0.443 |                   0.003 |
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_selected['Dataset'] = 'PPMI'
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fed_selected['Dataset'] = 'PPMI'
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_selected['Dataset'] = 'PPMI'
# /home/bdanek2/multi-omics-pdd-FL-study/federated_learning_multi_modality_ancestry/multi_modality_fl/results/compute_figures.py:379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fed_selected['Dataset'] = 'PPMI'

# %%
import pandas as pd

table_1 = f'{BASE_OUTPUT_PATH}/PPMI_n_2_clients_cleaned_combined.csv'
print("PPMI table 1, Performance of central and federated learning algorithms for N=2 clients (uniform stratified)")
print(pd.read_csv(table_1).to_markdown())
# Out:
# PPMI table 1, Performance of central and federated learning algorithms for N=2 clients (uniform stratified)
# |    | Dataset   | algorithm_name                | roc_auc_score   | auc_precision_recall   | balanced_accuracy_score   | precision_score   | recall_score   | fbeta_score_0.5   | fbeta_score_1   | fbeta_score_2   | log_loss    | matthews_corrcoef   |
# |---:|:----------|:------------------------------|:----------------|:-----------------------|:--------------------------|:------------------|:---------------|:------------------|:----------------|:----------------|:------------|:--------------------|
# |  0 | PPMI      | AdaBoost                      | 0.884±0.039     | 0.937±0.01             | 0.786±0.065               | 0.876±0.038       | 0.894±0.03     | 0.906±0.018       | 0.91±0.033      | 0.955±0.012     | 0.633±0.007 | 0.582±0.128         |
# |  1 | PPMI      | Bagging                       | 0.857±0.086     | 0.934±0.048            | 0.736±0.035               | 0.842±0.002       | 0.901±0.12     | 0.88±0.026        | 0.879±0.042     | 0.94±0.019      | 0.743±0.57  | 0.527±0.157         |
# |  2 | PPMI      | GradientBoosting              | 0.907±0.023     | 0.957±0.01             | 0.776±0.01                | 0.866±0.013       | 0.908±0.03     | 0.93±0.02         | 0.908±0.02      | 0.958±0.013     | 0.352±0.04  | 0.577±0.006         |
# |  3 | PPMI      | KNeighbors                    | 0.584±0.089     | 0.774±0.088            | 0.526±0.041               | 0.73±0.02         | 0.908±0.07     | 0.78±0.019        | 0.838±0.003     | 0.928±0.002     | 2.638±0.059 | 0.058±0.103         |
# |  4 | PPMI      | LinearDiscriminantAnalysis    | 0.784±0.051     | 0.881±0.058            | 0.723±0.09                | 0.865±0.053       | 0.732±0.08     | 0.442±0.625       | 0.435±0.615     | 0.468±0.662     | 1.457±0.512 | 0.413±0.172         |
# |  5 | PPMI      | LogisticRegression            | 0.825±0.023     | 0.907±0.039            | 0.758±0.06                | 0.861±0.037       | 0.873±0.02     | 0.882±0.013       | 0.881±0.02      | 0.937±0.0       | 0.662±0.044 | 0.521±0.114         |
# |  6 | PPMI      | MLP                           | 0.717±0.003     | 0.883±0.003            | 0.675±0.013               | 0.819±0.016       | 0.796±0.05     | 0.826±0.014       | 0.857±0.018     | 0.931±0.002     | 7.87±0.825  | 0.344±0.007         |
# |  7 | PPMI      | QuadraticDiscriminantAnalysis | 0.529±0.036     | 0.792±0.016            | 0.529±0.036               | 0.749±0.04        | 0.415±0.03     | 0.76±0.0          | 0.835±0.0       | 0.927±0.0       | 18.75±0.257 | 0.055±0.067         |
# |  8 | PPMI      | RandomForest                  | 0.883±0.028     | 0.942±0.003            | 0.536±0.025               | 0.732±0.011       | 1.0±0.0        | 0.888±0.028       | 0.906±0.03      | 0.956±0.016     | 0.486±0.014 | 0.221±0.085         |
# |  9 | PPMI      | SGD                           | 0.764±0.004     | 0.91±0.001             | 0.74±0.025                | 0.856±0.007       | 0.838±0.05     | 0.865±0.002       | 0.879±0.008     | 0.931±0.006     | 7.686±1.169 | 0.476±0.066         |
# | 10 | PPMI      | SVC                           | 0.857±0.019     | 0.932±0.011            | 0.735±0.013               | 0.839±0.008       | 0.915±0.0      | 0.882±0.015       | 0.894±0.011     | 0.939±0.005     | 0.413±0.012 | 0.512±0.021         |
# | 11 | PPMI      | XGB                           | 0.928±0.005     | 0.963±0.013            | 0.876±0.031               | 0.931±0.034       | 0.93±0.04      | 0.94±0.005        | 0.936±0.012     | 0.959±0.004     | 0.316±0.005 | 0.754±0.015         |
# | 12 | PPMI      | XGBRF                         | 0.933±0.022     | 0.971±0.004            | 0.844±0.011               | 0.916±0.03        | 0.901±0.08     | 0.953±0.029       | 0.94±0.024      | 0.948±0.01      | 0.806±0.142 | 0.689±0.039         |
# | 13 | PPMI      | FedAvg LR                     | 0.827±0.042     | 0.899±0.054            | 0.724±0.038               | 0.83±0.022        | 0.93±0.0       | 0.873±0.009       | 0.889±0.006     | 0.943±0.005     | 0.538±0.106 | 0.506±0.065         |
# | 14 | PPMI      | FedAvg MLP                    | 0.7±0.095       | 0.833±0.1              | 0.616±0.01                | 0.792±0.011       | 0.697±0.03     | 0.41±0.579        | 0.434±0.614     | 0.467±0.661     | 0.771±0.085 | 0.218±0.015         |
# | 15 | PPMI      | FedAvg SGD                    | 0.837±0.036     | 0.926±0.008            | 0.777±0.05                | 0.925±0.029       | 0.697±0.05     | 0.881±0.036       | 0.863±0.018     | 0.939±0.007     | 0.53±0.046  | 0.501±0.092         |
# | 16 | PPMI      | FedAvg XGBRF                  | 0.838±0.03      | 0.934±0.009            | 0.774±0.063               | 0.88±0.057        | 0.852±0.05     | 0.883±0.03        | 0.875±0.017     | 0.929±0.003     | 0.691±0.0   | 0.54±0.082          |
# | 17 | PPMI      | FedProx μ = 0 LR              | 0.832±0.064     | 0.901±0.066            | 0.67±0.028                | 0.8±0.017         | 0.93±0.02      | 0.447±0.632       | 0.449±0.636     | 0.478±0.677     | 0.531±0.164 | 0.412±0.032         |
# | 18 | PPMI      | FedProx μ = 0 MLP             | 0.731±0.042     | 0.852±0.068            | 0.645±0.005               | 0.805±0.002       | 0.754±0.01     | 0.831±0.018       | 0.858±0.011     | 0.938±0.005     | 0.98±0.077  | 0.277±0.011         |
# | 19 | PPMI      | FedProx μ = 2 LR              | 0.799±0.022     | 0.891±0.038            | 0.661±0.0                 | 0.795±0.0         | 0.93±0.0       | 0.859±0.006       | 0.87±0.009      | 0.94±0.009      | 0.565±0.049 | 0.395±0.0           |
# | 20 | PPMI      | FedProx μ = 2 MLP             | 0.736±0.062     | 0.846±0.082            | 0.645±0.046               | 0.805±0.032       | 0.754±0.01     | 0.415±0.587       | 0.43±0.609      | 0.465±0.657     | 0.785±0.091 | 0.277±0.08          |

# %%
table_2 = f'{BASE_OUTPUT_PATH}/PDBP_n_2_clients_cleaned_combined.csv'
print("PDBP table 2, Performance of central and federated learning algorithms for N=2 clients (uniform stratified)")
print(pd.read_csv(table_2).to_markdown())
# Out:
# PDBP table 2, Performance of central and federated learning algorithms for N=2 clients (uniform stratified)
# |    | Dataset   | algorithm_name                | roc_auc_score   | auc_precision_recall   | balanced_accuracy_score   | precision_score   | recall_score   | fbeta_score_0.5   | fbeta_score_1   | fbeta_score_2   | log_loss     | matthews_corrcoef   |
# |---:|:----------|:------------------------------|:----------------|:-----------------------|:--------------------------|:------------------|:---------------|:------------------|:----------------|:----------------|:-------------|:--------------------|
# |  0 | PPMI      | AdaBoost                      | 0.846±0.03      | 0.902±0.022            | 0.676±0.032               | 0.737±0.022       | 0.948±0.014    | 0.843±0.028       | 0.836±0.014     | 0.908±0.002     | 0.634±0.003  | 0.44±0.044          |
# |  1 | PPMI      | Bagging                       | 0.812±0.017     | 0.869±0.016            | 0.68±0.015                | 0.74±0.012        | 0.947±0.02     | 0.827±0.014       | 0.841±0.008     | 0.905±0.001     | 1.396±0.135  | 0.448±0.007         |
# |  2 | PPMI      | GradientBoosting              | 0.867±0.011     | 0.912±0.011            | 0.718±0.025               | 0.766±0.019       | 0.944±0.012    | 0.861±0.007       | 0.858±0.0       | 0.911±0.0       | 0.538±0.009  | 0.51±0.032          |
# |  3 | PPMI      | KNeighbors                    | 0.591±0.01      | 0.726±0.002            | 0.559±0.001               | 0.669±0.001       | 0.93±0.03      | 0.708±0.002       | 0.783±0.002     | 0.899±0.0       | 2.919±0.329  | 0.181±0.019         |
# |  4 | PPMI      | LinearDiscriminantAnalysis    | 0.702±0.024     | 0.79±0.014             | 0.645±0.025               | 0.739±0.019       | 0.771±0.006    | 0.748±0.018       | 0.794±0.011     | 0.9±0.003       | 1.971±0.043  | 0.295±0.048         |
# |  5 | PPMI      | LogisticRegression            | 0.768±0.003     | 0.838±0.003            | 0.661±0.005               | 0.733±0.002       | 0.899±0.01     | 0.788±0.0         | 0.81±0.004      | 0.9±0.002       | 0.992±0.027  | 0.375±0.016         |
# |  6 | PPMI      | MLP                           | 0.665±0.01      | 0.825±0.01             | 0.617±0.01                | 0.71±0.006        | 0.838±0.01     | 0.747±0.01        | 0.787±0.003     | 0.899±0.0       | 9.022±0.063  | 0.262±0.024         |
# |  7 | PPMI      | QuadraticDiscriminantAnalysis | 0.524±0.007     | 0.717±0.006            | 0.524±0.007               | 0.677±0.023       | 0.329±0.098    | 0.688±0.0         | 0.779±0.0       | 0.898±0.0       | 19.104±0.799 | 0.051±0.019         |
# |  8 | PPMI      | RandomForest                  | 0.735±0.005     | 0.827±0.0              | 0.521±0.004               | 0.648±0.002       | 0.989±0.001    | 0.761±0.008       | 0.794±0.004     | 0.899±0.0       | 0.597±0.003  | 0.129±0.014         |
# |  9 | PPMI      | SGD                           | 0.682±0.003     | 0.852±0.001            | 0.669±0.006               | 0.74±0.005        | 0.889±0.006    | 0.769±0.002       | 0.812±0.0       | 0.898±0.0       | 9.503±0.091  | 0.383±0.007         |
# | 10 | PPMI      | SVC                           | 0.705±0.013     | 0.81±0.008             | 0.592±0.017               | 0.692±0.009       | 0.856±0.029    | 0.742±0.008       | 0.793±0.003     | 0.901±0.001     | 0.633±0.018  | 0.218±0.046         |
# | 11 | PPMI      | XGB                           | 0.867±0.002     | 0.909±0.0              | 0.709±0.032               | 0.761±0.023       | 0.938±0.007    | 0.865±0.003       | 0.857±0.004     | 0.906±0.001     | 0.677±0.039  | 0.489±0.049         |
# | 12 | PPMI      | XGBRF                         | 0.837±0.0       | 0.896±0.001            | 0.728±0.015               | 0.778±0.014       | 0.919±0.017    | 0.85±0.001        | 0.856±0.001     | 0.908±0.001     | 2.514±0.101  | 0.509±0.014         |
# | 13 | PPMI      | FedAvg LR                     | 0.741±0.016     | 0.823±0.014            | 0.59±0.002                | 0.686±0.002       | 0.939±0.023    | 0.77±0.007        | 0.797±0.005     | 0.899±0.001     | 0.896±0.023  | 0.262±0.017         |
# | 14 | PPMI      | FedAvg MLP                    | 0.672±0.016     | 0.768±0.014            | 0.623±0.007               | 0.716±0.007       | 0.817±0.014    | 0.739±0.0         | 0.785±0.006     | 0.898±0.0       | 0.884±0.091  | 0.265±0.009         |
# | 15 | PPMI      | FedAvg SGD                    | 0.776±0.003     | 0.846±0.002            | 0.69±0.007                | 0.77±0.005        | 0.804±0.001    | 0.794±0.003       | 0.811±0.001     | 0.902±0.001     | 0.558±0.005  | 0.387±0.012         |
# | 16 | PPMI      | FedAvg XGBRF                  | 0.792±0.013     | 0.879±0.007            | 0.692±0.049               | 0.752±0.037       | 0.925±0.019    | 0.823±0.011       | 0.837±0.016     | 0.901±0.004     | 0.691±0.0    | 0.449±0.074         |
# | 17 | PPMI      | FedProx μ = 0 LR              | 0.735±0.022     | 0.812±0.019            | 0.595±0.007               | 0.689±0.003       | 0.93±0.017     | 0.772±0.015       | 0.796±0.004     | 0.9±0.001       | 0.912±0.056  | 0.266±0.028         |
# | 18 | PPMI      | FedProx μ = 0 MLP             | 0.701±0.0       | 0.794±0.008            | 0.62±0.01                 | 0.713±0.007       | 0.825±0.007    | 0.746±0.005       | 0.792±0.003     | 0.899±0.0       | 1.201±0.155  | 0.262±0.017         |
# | 19 | PPMI      | FedProx μ = 2 LR              | 0.754±0.009     | 0.828±0.008            | 0.596±0.003               | 0.688±0.003       | 0.956±0.016    | 0.782±0.004       | 0.803±0.002     | 0.899±0.001     | 0.864±0.012  | 0.293±0.01          |
# | 20 | PPMI      | FedProx μ = 2 MLP             | 0.676±0.016     | 0.773±0.012            | 0.606±0.003               | 0.705±0.004       | 0.802±0.016    | 0.733±0.01        | 0.788±0.005     | 0.899±0.0       | 1.134±0.443  | 0.228±0.003         |

# %%
import pandas as pd

table_3 = f'{BASE_OUTPUT_PATH}/global_experiments_k_all PPMI Uniform Stratified test_client_line_plot_table.csv'
table_4 = f'{BASE_OUTPUT_PATH}/global_experiments_k_all PDBP Uniform Stratified test_client_line_plot_table.csv'

print("PPMI table 3, AUC-PR vs. number of clients (uniform stratified)")
print(pd.read_csv(table_3).to_markdown())

print("")
print("PDBP table 4, AUC-PR vs. number of clients (uniform stratified)")
print(pd.read_csv(table_4).to_markdown())
# Out:
# PPMI table 3, AUC-PR vs. number of clients (uniform stratified)
# |    | algorithm_name    | 2             | 4             | 6             | 8             | 10            | 12            | 14            | 16            | 18            |
# |---:|:------------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|
# |  0 | FedAvg LR         | 0.899 ± 0.054 | 0.882 ± 0.071 | 0.89 ± 0.086  | 0.878 ± 0.07  | 0.883 ± 0.058 | 0.889 ± 0.057 | 0.89 ± 0.051  | 0.88 ± 0.059  | 0.881 ± 0.054 |
# |  1 | FedAvg MLP        | 0.833 ± 0.1   | 0.851 ± 0.099 | 0.842 ± 0.109 | 0.852 ± 0.057 | 0.87 ± 0.082  | 0.843 ± 0.086 | 0.853 ± 0.102 | 0.837 ± 0.103 | 0.858 ± 0.09  |
# |  2 | FedAvg SGD        | 0.926 ± 0.008 | 0.901 ± 0.033 | 0.899 ± 0.048 | 0.891 ± 0.079 | 0.888 ± 0.092 | 0.898 ± 0.061 | 0.887 ± 0.048 | 0.895 ± 0.064 | 0.889 ± 0.078 |
# |  3 | FedAvg XGBRF      | 0.934 ± 0.009 | 0.949 ± 0.012 | 0.948 ± 0.018 | 0.892 ± 0.009 | 0.911 ± 0.02  | 0.91 ± 0.019  | 0.898 ± 0.005 | 0.823 ± 0.063 | 0.826 ± 0.018 |
# |  4 | FedProx μ = 0 LR  | 0.901 ± 0.066 | 0.899 ± 0.051 | 0.897 ± 0.071 | 0.888 ± 0.054 | 0.877 ± 0.053 | 0.884 ± 0.061 | 0.882 ± 0.08  | 0.883 ± 0.067 | 0.873 ± 0.071 |
# |  5 | FedProx μ = 0 MLP | 0.852 ± 0.068 | 0.85 ± 0.098  | 0.846 ± 0.097 | 0.869 ± 0.071 | 0.866 ± 0.091 | 0.861 ± 0.114 | 0.857 ± 0.088 | 0.843 ± 0.112 | 0.842 ± 0.107 |
# |  6 | FedProx μ = 2 LR  | 0.891 ± 0.038 | 0.882 ± 0.061 | 0.889 ± 0.074 | 0.891 ± 0.068 | 0.872 ± 0.066 | 0.879 ± 0.058 | 0.881 ± 0.07  | 0.877 ± 0.081 | 0.877 ± 0.068 |
# |  7 | FedProx μ = 2 MLP | 0.846 ± 0.082 | 0.831 ± 0.107 | 0.844 ± 0.099 | 0.859 ± 0.099 | 0.858 ± 0.089 | 0.847 ± 0.093 | 0.866 ± 0.063 | 0.846 ± 0.101 | 0.86 ± 0.079  |
#
# PDBP table 4, AUC-PR vs. number of clients (uniform stratified)
# |    | algorithm_name    | 2             | 4             | 6             | 8             | 10            | 12            | 14            | 16            | 18            |
# |---:|:------------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|:--------------|
# |  0 | FedAvg LR         | 0.823 ± 0.014 | 0.799 ± 0.009 | 0.8 ± 0.011   | 0.787 ± 0.007 | 0.788 ± 0.009 | 0.791 ± 0.007 | 0.787 ± 0.01  | 0.781 ± 0.005 | 0.78 ± 0.008  |
# |  1 | FedAvg MLP        | 0.768 ± 0.014 | 0.788 ± 0.022 | 0.775 ± 0.009 | 0.78 ± 0.005  | 0.809 ± 0.014 | 0.77 ± 0.019  | 0.792 ± 0.012 | 0.778 ± 0.006 | 0.783 ± 0.012 |
# |  2 | FedAvg SGD        | 0.846 ± 0.002 | 0.821 ± 0.014 | 0.822 ± 0.017 | 0.815 ± 0.014 | 0.8 ± 0.005   | 0.804 ± 0.005 | 0.796 ± 0.022 | 0.801 ± 0.004 | 0.787 ± 0.012 |
# |  3 | FedAvg XGBRF      | 0.879 ± 0.007 | 0.872 ± 0.004 | 0.867 ± 0.019 | 0.828 ± 0.018 | 0.815 ± 0.007 | 0.817 ± 0.026 | 0.812 ± 0.062 | 0.715 ± 0.037 | 0.699 ± 0.058 |
# |  4 | FedProx μ = 0 LR  | 0.812 ± 0.019 | 0.826 ± 0.005 | 0.793 ± 0.003 | 0.784 ± 0.007 | 0.785 ± 0.001 | 0.787 ± 0.005 | 0.776 ± 0.008 | 0.788 ± 0.011 | 0.78 ± 0.013  |
# |  5 | FedProx μ = 0 MLP | 0.794 ± 0.008 | 0.793 ± 0.022 | 0.781 ± 0.018 | 0.797 ± 0.006 | 0.791 ± 0.018 | 0.79 ± 0.016  | 0.788 ± 0.011 | 0.787 ± 0.017 | 0.771 ± 0.02  |
# |  6 | FedProx μ = 2 LR  | 0.828 ± 0.008 | 0.807 ± 0.005 | 0.807 ± 0.005 | 0.805 ± 0.01  | 0.781 ± 0.009 | 0.783 ± 0.005 | 0.783 ± 0.01  | 0.787 ± 0.012 | 0.775 ± 0.006 |
# |  7 | FedProx μ = 2 MLP | 0.773 ± 0.012 | 0.8 ± 0.019   | 0.777 ± 0.006 | 0.784 ± 0.011 | 0.792 ± 0.011 | 0.782 ± 0.01  | 0.795 ± 0.016 | 0.78 ± 0.017  | 0.791 ± 0.021 |
