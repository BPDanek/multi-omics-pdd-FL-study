# %%
import pandas as pd

internal_results_path = '/Users/benjamindanek/Code/federated_learning_multi_modality_ancestry/multi_modality_fl/results/generated_figures_tables/k_averaged_results_table_k_all PPMI Uniform Stratified test.csv'
external_results_path = '/Users/benjamindanek/Code/federated_learning_multi_modality_ancestry/multi_modality_fl/results/generated_figures_tables/k_averaged_results_table_k_all PDBP Uniform Stratified test.csv'

# %%
internal_data = pd.read_csv(internal_results_path)
extermal_data = pd.read_csv(external_results_path)

# %%
dataset = "PPMI"
baseline_selected = internal_data[internal_data['num_clients'] == 0]
baseline_selected['Dataset'] = 'PPMI'

internal_selected = internal_data[internal_data['num_clients'] == 2]
internal_selected['Dataset'] = 'PPMI'

combined = pd.concat([baseline_selected, internal_selected])

# dataset = "PDBP"
# baseline_selected = extermal_data[internal_data['num_clients'] == 0]
# baseline_selected['Dataset'] = 'PDBP'

# external_selected = extermal_data[internal_data['num_clients'] == 2]
# external_selected['Dataset'] = 'PDBP'

# combined = pd.concat([baseline_selected, external_selected])
# Out:
# /var/folders/z7/3z1ynh754yddqxjrz2zz7d2c0000gn/T/ipykernel_22259/1290954036.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baseline_selected['Dataset'] = 'PPMI'
# /var/folders/z7/3z1ynh754yddqxjrz2zz7d2c0000gn/T/ipykernel_22259/1290954036.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internal_selected['Dataset'] = 'PPMI'

# %%
combined['algorithm_name'] = combined['algorithm_name'].apply(lambda x: x.replace('Classifier', '') if type(x) == str else x)
combined_clean = combined.set_index(['Dataset', 'algorithm_name']).drop(columns=['num_clients', 'split_method', 'val_name', 'fold_idx', 'num_clients_std', 'split_method_std', 'val_name_std', 'fold_idx_std', 'algorithm_name_std'])
combined_clean = combined_clean.round(3)
display(combined_clean)
# Out:
#                                        roc_auc_score  auc_precision_recall  \
# Dataset algorithm_name
# PPMI    AdaBoost                               0.865                 0.939
#         Bagging                                0.820                 0.916
#         GradientBoosting                       0.879                 0.943
#         KNeighbors                             0.610                 0.806
#         LinearDiscriminantAnalysis             0.763                 0.883
#         LogisticRegression                     0.831                 0.915
#         MLP                                    0.739                 0.892
#         QuadraticDiscriminantAnalysis          0.504                 0.774
#         RandomForest                           0.816                 0.917
#         SGD                                    0.755                 0.907
#         SVC                                    0.838                 0.924
#         XGB                                    0.890                 0.953
#         XGBRF                                  0.857                 0.936
#         FedAvg LR                              0.690                 0.874
#         FedAvg MLP                             0.760                 0.872
#         FedAvg SGD                             0.828                 0.920
#         FedAvg XGBRF                           0.829                 0.924
#         FedProx μ = 0 LR                       0.755                 0.887
#         FedProx μ = 0 MLP                      0.757                 0.872
#         FedProx μ = 2 LR                       0.812                 0.906
#         FedProx μ = 2 MLP                      0.765                 0.868
#
#                                        balanced_accuracy_score  \
# Dataset algorithm_name
# PPMI    AdaBoost                                         0.736
#         Bagging                                          0.690
#         GradientBoosting                                 0.723
#         KNeighbors                                       0.533
#         LinearDiscriminantAnalysis                       0.681
#         LogisticRegression                               0.734
#         MLP                                              0.703
#         QuadraticDiscriminantAnalysis                    0.504
#         RandomForest                                     0.552
#         SGD                                              0.735
#         SVC                                              0.711
#         XGB                                              0.765
#         XGBRF                                            0.773
#         FedAvg LR                                        0.617
#         FedAvg MLP                                       0.671
#         FedAvg SGD                                       0.757
#         FedAvg XGBRF                                     0.739
#         FedProx μ = 0 LR                                 0.653
#         FedProx μ = 0 MLP                                0.695
#         FedProx μ = 2 LR                                 0.658
#         FedProx μ = 2 MLP                                0.694
#
#                                        precision_score  recall_score  \
# Dataset algorithm_name
# PPMI    AdaBoost                                 0.844         0.890
#         Bagging                                  0.813         0.897
#         GradientBoosting                         0.833         0.911
#         KNeighbors                               0.729         0.937
#         LinearDiscriminantAnalysis               0.826         0.770
#         LogisticRegression                       0.841         0.894
#         MLP                                      0.833         0.815
#         QuadraticDiscriminantAnalysis            0.725         0.385
#         RandomForest                             0.736         0.993
#         SGD                                      0.846         0.857
#         SVC                                      0.827         0.883
#         XGB                                      0.860         0.911
#         XGBRF                                    0.868         0.885
#         FedAvg LR                                0.772         0.955
#         FedAvg MLP                               0.817         0.768
#         FedAvg SGD                               0.904         0.707
#         FedAvg XGBRF                             0.848         0.883
#         FedProx μ = 0 LR                         0.791         0.941
#         FedProx μ = 0 MLP                        0.829         0.808
#         FedProx μ = 2 LR                         0.790         0.937
#         FedProx μ = 2 MLP                        0.830         0.798
#
#                                        fbeta_score_0.5  fbeta_score_1  \
# Dataset algorithm_name
# PPMI    AdaBoost                                 0.897          0.885
#         Bagging                                  0.865          0.862
#         GradientBoosting                         0.916          0.894
#         KNeighbors                               0.782          0.837
#         LinearDiscriminantAnalysis               0.700          0.714
#         LogisticRegression                       0.872          0.883
#         MLP                                      0.843          0.858
#         QuadraticDiscriminantAnalysis            0.757          0.833
#         RandomForest                             0.857          0.874
#         SGD                                      0.857          0.876
#         SVC                                      0.872          0.886
#         XGB                                      0.915          0.900
#         XGBRF                                    0.907          0.891
#         FedAvg LR                                0.818          0.863
#         FedAvg MLP                               0.708          0.728
#         FedAvg SGD                               0.871          0.872
#         FedAvg XGBRF                             0.886          0.875
#         FedProx μ = 0 LR                         0.704          0.729
#         FedProx μ = 0 MLP                        0.843          0.868
#         FedProx μ = 2 LR                         0.866          0.879
#         FedProx μ = 2 MLP                        0.706          0.724
#
#                                        fbeta_score_2  log_loss  \
# Dataset algorithm_name
# PPMI    AdaBoost                               0.942     0.632
#         Bagging                                0.933     1.001
#         GradientBoosting                       0.942     0.444
#         KNeighbors                             0.927     2.836
#         LinearDiscriminantAnalysis             0.776     1.608
#         LogisticRegression                     0.939     0.648
#         MLP                                    0.932     6.616
#         QuadraticDiscriminantAnalysis          0.926    19.674
#         RandomForest                           0.942     0.508
#         SGD                                    0.936     7.525
#         SVC                                    0.941     0.440
#         XGB                                    0.942     0.461
#         XGBRF                                  0.936     1.790
#         FedAvg LR                              0.935     0.655
#         FedAvg MLP                             0.779     0.767
#         FedAvg SGD                             0.939     0.545
#         FedAvg XGBRF                           0.929     0.691
#         FedProx μ = 0 LR                       0.784     0.609
#         FedProx μ = 0 MLP                      0.937     0.976
#         FedProx μ = 2 LR                       0.941     0.582
#         FedProx μ = 2 MLP                      0.781     0.900
#
#                                        matthews_corrcoef  roc_auc_score_std  \
# Dataset algorithm_name
# PPMI    AdaBoost                                   0.499              0.033
#         Bagging                                    0.428              0.050
#         GradientBoosting                           0.486              0.046
#         KNeighbors                                 0.111              0.099
#         LinearDiscriminantAnalysis                 0.347              0.045
#         LogisticRegression                         0.493              0.068
#         MLP                                        0.402              0.078
#         QuadraticDiscriminantAnalysis              0.009              0.057
#         RandomForest                               0.249              0.076
#         SGD                                        0.481              0.065
#         SVC                                        0.447              0.069
#         XGB                                        0.557              0.046
#         XGBRF                                      0.558              0.064
#         FedAvg LR                                  0.278              0.160
#         FedAvg MLP                                 0.334              0.102
#         FedAvg SGD                                 0.470              0.048
#         FedAvg XGBRF                               0.497              0.023
#         FedProx μ = 0 LR                           0.362              0.142
#         FedProx μ = 0 MLP                          0.387              0.096
#         FedProx μ = 2 LR                           0.398              0.079
#         FedProx μ = 2 MLP                          0.379              0.079
#
#                                        auc_precision_recall_std  \
# Dataset algorithm_name
# PPMI    AdaBoost                                          0.010
#         Bagging                                           0.025
#         GradientBoosting                                  0.026
#         KNeighbors                                        0.065
#         LinearDiscriminantAnalysis                        0.031
#         LogisticRegression                                0.039
#         MLP                                               0.032
#         QuadraticDiscriminantAnalysis                     0.029
#         RandomForest                                      0.027
#         SGD                                               0.025
#         SVC                                               0.032
#         XGB                                               0.018
#         XGBRF                                             0.029
#         FedAvg LR                                         0.042
#         FedAvg MLP                                        0.072
#         FedAvg SGD                                        0.025
#         FedAvg XGBRF                                      0.015
#         FedProx μ = 0 LR                                  0.041
#         FedProx μ = 0 MLP                                 0.061
#         FedProx μ = 2 LR                                  0.040
#         FedProx μ = 2 MLP                                 0.060
#
#                                        balanced_accuracy_score_std  \
# Dataset algorithm_name
# PPMI    AdaBoost                                             0.069
#         Bagging                                              0.052
#         GradientBoosting                                     0.072
#         KNeighbors                                           0.029
#         LinearDiscriminantAnalysis                           0.053
#         LogisticRegression                                   0.072
#         MLP                                                  0.059
#         QuadraticDiscriminantAnalysis                        0.057
#         RandomForest                                         0.034
#         SGD                                                  0.062
#         SVC                                                  0.071
#         XGB                                                  0.097
#         XGBRF                                                0.057
#         FedAvg LR                                            0.109
#         FedAvg MLP                                           0.087
#         FedAvg SGD                                           0.048
#         FedAvg XGBRF                                         0.058
#         FedProx μ = 0 LR                                     0.088
#         FedProx μ = 0 MLP                                    0.088
#         FedProx μ = 2 LR                                     0.028
#         FedProx μ = 2 MLP                                    0.069
#
#                                        precision_score_std  recall_score_std  \
# Dataset algorithm_name
# PPMI    AdaBoost                                     0.043             0.047
#         Bagging                                      0.027             0.061
#         GradientBoosting                             0.042             0.021
#         KNeighbors                                   0.014             0.046
#         LinearDiscriminantAnalysis                   0.040             0.050
#         LogisticRegression                           0.043             0.028
#         MLP                                          0.038             0.054
#         QuadraticDiscriminantAnalysis                0.055             0.081
#         RandomForest                                 0.016             0.017
#         SGD                                          0.032             0.068
#         SVC                                          0.041             0.042
#         XGB                                          0.062             0.030
#         XGBRF                                        0.040             0.047
#         FedAvg LR                                    0.054             0.037
#         FedAvg MLP                                   0.051             0.089
#         FedAvg SGD                                   0.049             0.033
#         FedAvg XGBRF                                 0.043             0.036
#         FedProx μ = 0 LR                             0.042             0.031
#         FedProx μ = 0 MLP                            0.048             0.075
#         FedProx μ = 2 LR                             0.014             0.025
#         FedProx μ = 2 MLP                            0.042             0.045
#
#                                        fbeta_score_0.5_std  fbeta_score_1_std  \
# Dataset algorithm_name
# PPMI    AdaBoost                                     0.017              0.027
#         Bagging                                      0.021              0.024
#         GradientBoosting                             0.030              0.022
#         KNeighbors                                   0.023              0.007
#         LinearDiscriminantAnalysis                   0.344              0.350
#         LogisticRegression                           0.047              0.033
#         MLP                                          0.038              0.034
#         QuadraticDiscriminantAnalysis                0.008              0.006
#         RandomForest                                 0.043              0.032
#         SGD                                          0.037              0.036
#         SVC                                          0.042              0.024
#         XGB                                          0.030              0.033
#         XGBRF                                        0.039              0.041
#         FedAvg LR                                    0.054              0.026
#         FedAvg MLP                                   0.350              0.358
#         FedAvg SGD                                   0.032              0.018
#         FedAvg XGBRF                                 0.020              0.012
#         FedProx μ = 0 LR                             0.349              0.358
#         FedProx μ = 0 MLP                            0.042              0.028
#         FedProx μ = 2 LR                             0.045              0.025
#         FedProx μ = 2 MLP                            0.348              0.355
#
#                                        fbeta_score_2_std  log_loss_std  \
# Dataset algorithm_name
# PPMI    AdaBoost                                   0.013         0.007
#         Bagging                                    0.010         0.382
#         GradientBoosting                           0.015         0.099
#         KNeighbors                                 0.004         0.617
#         LinearDiscriminantAnalysis                 0.380         0.488
#         LogisticRegression                         0.011         0.203
#         MLP                                        0.013         1.844
#         QuadraticDiscriminantAnalysis              0.003         1.492
#         RandomForest                               0.014         0.029
#         SGD                                        0.015         2.282
#         SVC                                        0.008         0.082
#         XGB                                        0.014         0.135
#         XGBRF                                      0.011         0.853
#         FedAvg LR                                  0.008         0.140
#         FedAvg MLP                                 0.382         0.308
#         FedAvg SGD                                 0.008         0.032
#         FedAvg XGBRF                               0.005         0.000
#         FedProx μ = 0 LR                           0.384         0.155
#         FedProx μ = 0 MLP                          0.004         0.314
#         FedProx μ = 2 LR                           0.006         0.137
#         FedProx μ = 2 MLP                          0.382         0.368
#
#                                        matthews_corrcoef_std
# Dataset algorithm_name
# PPMI    AdaBoost                                       0.122
#         Bagging                                        0.123
#         GradientBoosting                               0.119
#         KNeighbors                                     0.104
#         LinearDiscriminantAnalysis                     0.095
#         LogisticRegression                             0.134
#         MLP                                            0.119
#         QuadraticDiscriminantAnalysis                  0.105
#         RandomForest                                   0.121
#         SGD                                            0.143
#         SVC                                            0.145
#         XGB                                            0.167
#         XGBRF                                          0.105
#         FedAvg LR                                      0.250
#         FedAvg MLP                                     0.179
#         FedAvg SGD                                     0.084
#         FedAvg XGBRF                                   0.089
#         FedProx μ = 0 LR                               0.198
#         FedProx μ = 0 MLP                              0.182
#         FedProx μ = 2 LR                               0.069
#         FedProx μ = 2 MLP                              0.133

# %%
vanilla = []
for c in combined_clean.columns:
    if '_std' not in c:
        vanilla.append(c)
    

for v in vanilla:
    c = v + '_std'
    combined_clean[v] = combined_clean[v].astype(str) + '±' + combined_clean[c].astype(str)
    combined_clean = combined_clean.drop(columns=[c])

display(combined_clean)
# Out:
#                                       roc_auc_score auc_precision_recall  \
# Dataset algorithm_name
# PPMI    AdaBoost                        0.865±0.033           0.939±0.01
#         Bagging                           0.82±0.05          0.916±0.025
#         GradientBoosting                0.879±0.046          0.943±0.026
#         KNeighbors                       0.61±0.099          0.806±0.065
#         LinearDiscriminantAnalysis      0.763±0.045          0.883±0.031
#         LogisticRegression              0.831±0.068          0.915±0.039
#         MLP                             0.739±0.078          0.892±0.032
#         QuadraticDiscriminantAnalysis   0.504±0.057          0.774±0.029
#         RandomForest                    0.816±0.076          0.917±0.027
#         SGD                             0.755±0.065          0.907±0.025
#         SVC                             0.838±0.069          0.924±0.032
#         XGB                              0.89±0.046          0.953±0.018
#         XGBRF                           0.857±0.064          0.936±0.029
#         FedAvg LR                         0.69±0.16          0.874±0.042
#         FedAvg MLP                       0.76±0.102          0.872±0.072
#         FedAvg SGD                      0.828±0.048           0.92±0.025
#         FedAvg XGBRF                    0.829±0.023          0.924±0.015
#         FedProx μ = 0 LR                0.755±0.142          0.887±0.041
#         FedProx μ = 0 MLP               0.757±0.096          0.872±0.061
#         FedProx μ = 2 LR                0.812±0.079           0.906±0.04
#         FedProx μ = 2 MLP               0.765±0.079           0.868±0.06
#
#                                       balanced_accuracy_score precision_score  \
# Dataset algorithm_name
# PPMI    AdaBoost                                  0.736±0.069     0.844±0.043
#         Bagging                                    0.69±0.052     0.813±0.027
#         GradientBoosting                          0.723±0.072     0.833±0.042
#         KNeighbors                                0.533±0.029     0.729±0.014
#         LinearDiscriminantAnalysis                0.681±0.053      0.826±0.04
#         LogisticRegression                        0.734±0.072     0.841±0.043
#         MLP                                       0.703±0.059     0.833±0.038
#         QuadraticDiscriminantAnalysis             0.504±0.057     0.725±0.055
#         RandomForest                              0.552±0.034     0.736±0.016
#         SGD                                       0.735±0.062     0.846±0.032
#         SVC                                       0.711±0.071     0.827±0.041
#         XGB                                       0.765±0.097      0.86±0.062
#         XGBRF                                     0.773±0.057      0.868±0.04
#         FedAvg LR                                 0.617±0.109     0.772±0.054
#         FedAvg MLP                                0.671±0.087     0.817±0.051
#         FedAvg SGD                                0.757±0.048     0.904±0.049
#         FedAvg XGBRF                              0.739±0.058     0.848±0.043
#         FedProx μ = 0 LR                          0.653±0.088     0.791±0.042
#         FedProx μ = 0 MLP                         0.695±0.088     0.829±0.048
#         FedProx μ = 2 LR                          0.658±0.028      0.79±0.014
#         FedProx μ = 2 MLP                         0.694±0.069      0.83±0.042
#
#                                       recall_score fbeta_score_0.5  \
# Dataset algorithm_name
# PPMI    AdaBoost                        0.89±0.047     0.897±0.017
#         Bagging                        0.897±0.061     0.865±0.021
#         GradientBoosting               0.911±0.021      0.916±0.03
#         KNeighbors                     0.937±0.046     0.782±0.023
#         LinearDiscriminantAnalysis       0.77±0.05       0.7±0.344
#         LogisticRegression             0.894±0.028     0.872±0.047
#         MLP                            0.815±0.054     0.843±0.038
#         QuadraticDiscriminantAnalysis  0.385±0.081     0.757±0.008
#         RandomForest                   0.993±0.017     0.857±0.043
#         SGD                            0.857±0.068     0.857±0.037
#         SVC                            0.883±0.042     0.872±0.042
#         XGB                             0.911±0.03      0.915±0.03
#         XGBRF                          0.885±0.047     0.907±0.039
#         FedAvg LR                      0.955±0.037     0.818±0.054
#         FedAvg MLP                     0.768±0.089      0.708±0.35
#         FedAvg SGD                     0.707±0.033     0.871±0.032
#         FedAvg XGBRF                   0.883±0.036      0.886±0.02
#         FedProx μ = 0 LR               0.941±0.031     0.704±0.349
#         FedProx μ = 0 MLP              0.808±0.075     0.843±0.042
#         FedProx μ = 2 LR               0.937±0.025     0.866±0.045
#         FedProx μ = 2 MLP              0.798±0.045     0.706±0.348
#
#                                       fbeta_score_1 fbeta_score_2  \
# Dataset algorithm_name
# PPMI    AdaBoost                        0.885±0.027   0.942±0.013
#         Bagging                         0.862±0.024    0.933±0.01
#         GradientBoosting                0.894±0.022   0.942±0.015
#         KNeighbors                      0.837±0.007   0.927±0.004
#         LinearDiscriminantAnalysis       0.714±0.35    0.776±0.38
#         LogisticRegression              0.883±0.033   0.939±0.011
#         MLP                             0.858±0.034   0.932±0.013
#         QuadraticDiscriminantAnalysis   0.833±0.006   0.926±0.003
#         RandomForest                    0.874±0.032   0.942±0.014
#         SGD                             0.876±0.036   0.936±0.015
#         SVC                             0.886±0.024   0.941±0.008
#         XGB                               0.9±0.033   0.942±0.014
#         XGBRF                           0.891±0.041   0.936±0.011
#         FedAvg LR                       0.863±0.026   0.935±0.008
#         FedAvg MLP                      0.728±0.358   0.779±0.382
#         FedAvg SGD                      0.872±0.018   0.939±0.008
#         FedAvg XGBRF                    0.875±0.012   0.929±0.005
#         FedProx μ = 0 LR                0.729±0.358   0.784±0.384
#         FedProx μ = 0 MLP               0.868±0.028   0.937±0.004
#         FedProx μ = 2 LR                0.879±0.025   0.941±0.006
#         FedProx μ = 2 MLP               0.724±0.355   0.781±0.382
#
#                                            log_loss matthews_corrcoef
# Dataset algorithm_name
# PPMI    AdaBoost                        0.632±0.007       0.499±0.122
#         Bagging                         1.001±0.382       0.428±0.123
#         GradientBoosting                0.444±0.099       0.486±0.119
#         KNeighbors                      2.836±0.617       0.111±0.104
#         LinearDiscriminantAnalysis      1.608±0.488       0.347±0.095
#         LogisticRegression              0.648±0.203       0.493±0.134
#         MLP                             6.616±1.844       0.402±0.119
#         QuadraticDiscriminantAnalysis  19.674±1.492       0.009±0.105
#         RandomForest                    0.508±0.029       0.249±0.121
#         SGD                             7.525±2.282       0.481±0.143
#         SVC                              0.44±0.082       0.447±0.145
#         XGB                             0.461±0.135       0.557±0.167
#         XGBRF                            1.79±0.853       0.558±0.105
#         FedAvg LR                        0.655±0.14        0.278±0.25
#         FedAvg MLP                      0.767±0.308       0.334±0.179
#         FedAvg SGD                      0.545±0.032        0.47±0.084
#         FedAvg XGBRF                      0.691±0.0       0.497±0.089
#         FedProx μ = 0 LR                0.609±0.155       0.362±0.198
#         FedProx μ = 0 MLP               0.976±0.314       0.387±0.182
#         FedProx μ = 2 LR                0.582±0.137       0.398±0.069
#         FedProx μ = 2 MLP                 0.9±0.368       0.379±0.133

# %%
display(combined_clean)
# combined_clean['algorithm_name'].apply(lambda x: x.replace('Classifier', '') if type(x) == str else x)
# Out:
#                                       roc_auc_score auc_precision_recall  \
# Dataset algorithm_name
# PPMI    AdaBoost                        0.865±0.033           0.939±0.01
#         Bagging                           0.82±0.05          0.916±0.025
#         GradientBoosting                0.879±0.046          0.943±0.026
#         KNeighbors                       0.61±0.099          0.806±0.065
#         LinearDiscriminantAnalysis      0.763±0.045          0.883±0.031
#         LogisticRegression              0.831±0.068          0.915±0.039
#         MLP                             0.739±0.078          0.892±0.032
#         QuadraticDiscriminantAnalysis   0.504±0.057          0.774±0.029
#         RandomForest                    0.816±0.076          0.917±0.027
#         SGD                             0.755±0.065          0.907±0.025
#         SVC                             0.838±0.069          0.924±0.032
#         XGB                              0.89±0.046          0.953±0.018
#         XGBRF                           0.857±0.064          0.936±0.029
#         FedAvg LR                         0.69±0.16          0.874±0.042
#         FedAvg MLP                       0.76±0.102          0.872±0.072
#         FedAvg SGD                      0.828±0.048           0.92±0.025
#         FedAvg XGBRF                    0.829±0.023          0.924±0.015
#         FedProx μ = 0 LR                0.755±0.142          0.887±0.041
#         FedProx μ = 0 MLP               0.757±0.096          0.872±0.061
#         FedProx μ = 2 LR                0.812±0.079           0.906±0.04
#         FedProx μ = 2 MLP               0.765±0.079           0.868±0.06
#
#                                       balanced_accuracy_score precision_score  \
# Dataset algorithm_name
# PPMI    AdaBoost                                  0.736±0.069     0.844±0.043
#         Bagging                                    0.69±0.052     0.813±0.027
#         GradientBoosting                          0.723±0.072     0.833±0.042
#         KNeighbors                                0.533±0.029     0.729±0.014
#         LinearDiscriminantAnalysis                0.681±0.053      0.826±0.04
#         LogisticRegression                        0.734±0.072     0.841±0.043
#         MLP                                       0.703±0.059     0.833±0.038
#         QuadraticDiscriminantAnalysis             0.504±0.057     0.725±0.055
#         RandomForest                              0.552±0.034     0.736±0.016
#         SGD                                       0.735±0.062     0.846±0.032
#         SVC                                       0.711±0.071     0.827±0.041
#         XGB                                       0.765±0.097      0.86±0.062
#         XGBRF                                     0.773±0.057      0.868±0.04
#         FedAvg LR                                 0.617±0.109     0.772±0.054
#         FedAvg MLP                                0.671±0.087     0.817±0.051
#         FedAvg SGD                                0.757±0.048     0.904±0.049
#         FedAvg XGBRF                              0.739±0.058     0.848±0.043
#         FedProx μ = 0 LR                          0.653±0.088     0.791±0.042
#         FedProx μ = 0 MLP                         0.695±0.088     0.829±0.048
#         FedProx μ = 2 LR                          0.658±0.028      0.79±0.014
#         FedProx μ = 2 MLP                         0.694±0.069      0.83±0.042
#
#                                       recall_score fbeta_score_0.5  \
# Dataset algorithm_name
# PPMI    AdaBoost                        0.89±0.047     0.897±0.017
#         Bagging                        0.897±0.061     0.865±0.021
#         GradientBoosting               0.911±0.021      0.916±0.03
#         KNeighbors                     0.937±0.046     0.782±0.023
#         LinearDiscriminantAnalysis       0.77±0.05       0.7±0.344
#         LogisticRegression             0.894±0.028     0.872±0.047
#         MLP                            0.815±0.054     0.843±0.038
#         QuadraticDiscriminantAnalysis  0.385±0.081     0.757±0.008
#         RandomForest                   0.993±0.017     0.857±0.043
#         SGD                            0.857±0.068     0.857±0.037
#         SVC                            0.883±0.042     0.872±0.042
#         XGB                             0.911±0.03      0.915±0.03
#         XGBRF                          0.885±0.047     0.907±0.039
#         FedAvg LR                      0.955±0.037     0.818±0.054
#         FedAvg MLP                     0.768±0.089      0.708±0.35
#         FedAvg SGD                     0.707±0.033     0.871±0.032
#         FedAvg XGBRF                   0.883±0.036      0.886±0.02
#         FedProx μ = 0 LR               0.941±0.031     0.704±0.349
#         FedProx μ = 0 MLP              0.808±0.075     0.843±0.042
#         FedProx μ = 2 LR               0.937±0.025     0.866±0.045
#         FedProx μ = 2 MLP              0.798±0.045     0.706±0.348
#
#                                       fbeta_score_1 fbeta_score_2  \
# Dataset algorithm_name
# PPMI    AdaBoost                        0.885±0.027   0.942±0.013
#         Bagging                         0.862±0.024    0.933±0.01
#         GradientBoosting                0.894±0.022   0.942±0.015
#         KNeighbors                      0.837±0.007   0.927±0.004
#         LinearDiscriminantAnalysis       0.714±0.35    0.776±0.38
#         LogisticRegression              0.883±0.033   0.939±0.011
#         MLP                             0.858±0.034   0.932±0.013
#         QuadraticDiscriminantAnalysis   0.833±0.006   0.926±0.003
#         RandomForest                    0.874±0.032   0.942±0.014
#         SGD                             0.876±0.036   0.936±0.015
#         SVC                             0.886±0.024   0.941±0.008
#         XGB                               0.9±0.033   0.942±0.014
#         XGBRF                           0.891±0.041   0.936±0.011
#         FedAvg LR                       0.863±0.026   0.935±0.008
#         FedAvg MLP                      0.728±0.358   0.779±0.382
#         FedAvg SGD                      0.872±0.018   0.939±0.008
#         FedAvg XGBRF                    0.875±0.012   0.929±0.005
#         FedProx μ = 0 LR                0.729±0.358   0.784±0.384
#         FedProx μ = 0 MLP               0.868±0.028   0.937±0.004
#         FedProx μ = 2 LR                0.879±0.025   0.941±0.006
#         FedProx μ = 2 MLP               0.724±0.355   0.781±0.382
#
#                                            log_loss matthews_corrcoef
# Dataset algorithm_name
# PPMI    AdaBoost                        0.632±0.007       0.499±0.122
#         Bagging                         1.001±0.382       0.428±0.123
#         GradientBoosting                0.444±0.099       0.486±0.119
#         KNeighbors                      2.836±0.617       0.111±0.104
#         LinearDiscriminantAnalysis      1.608±0.488       0.347±0.095
#         LogisticRegression              0.648±0.203       0.493±0.134
#         MLP                             6.616±1.844       0.402±0.119
#         QuadraticDiscriminantAnalysis  19.674±1.492       0.009±0.105
#         RandomForest                    0.508±0.029       0.249±0.121
#         SGD                             7.525±2.282       0.481±0.143
#         SVC                              0.44±0.082       0.447±0.145
#         XGB                             0.461±0.135       0.557±0.167
#         XGBRF                            1.79±0.853       0.558±0.105
#         FedAvg LR                        0.655±0.14        0.278±0.25
#         FedAvg MLP                      0.767±0.308       0.334±0.179
#         FedAvg SGD                      0.545±0.032        0.47±0.084
#         FedAvg XGBRF                      0.691±0.0       0.497±0.089
#         FedProx μ = 0 LR                0.609±0.155       0.362±0.198
#         FedProx μ = 0 MLP               0.976±0.314       0.387±0.182
#         FedProx μ = 2 LR                0.582±0.137       0.398±0.069
#         FedProx μ = 2 MLP                 0.9±0.368       0.379±0.133

# %%
combined_clean.to_csv(f'/Users/benjamindanek/Code/federated_learning_multi_modality_ancestry/multi_modality_fl/results/generated_figures_tables/{dataset}_n_2_clients_cleaned_combined.csv')
